# %%
import requests
import os
import sqlalchemy as alch
from dotenv import load_dotenv
load_dotenv()
import pandas as pd
import time
from pymongo import MongoClient

# %%
passw = os.getenv("mysql")
dbName = "musicablecero"
connectionData = f"mysql+pymysql://root:{passw}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %% [markdown]
# # Api musicbrainz

# %%
base = 'https://musicbrainz.org/ws/2/'

# %%
artista = 'The%20beatles'

# %%
artistq = f'http://musicbrainz.org/ws/2/artist/?query=artist:{artista}&fmt=json'

# %%
req = requests.get(artistq).json()

# %%
req.keys()
# Out:
# dict_keys(['created', 'count', 'offset', 'artists'])

# %%
req['created']
# Out:
# '2022-03-14T18:10:00.913Z'

# %%
req['count']
# Out:
# 95993

# %%
req['offset']
# Out:
# 0

# %%
for r in req['artists']:
    print(r['name'])
# Out:
# The Beatles
# The Tape-beatles
# Blues Beatles
# Instrumental Beatles
# Sex Beatles
# The Silver Beetles
# Powdered Beatles
# Tokyo Beatles
# Beatles Chillout
# Zyklon Beatles
# Counterfeit Beatles
# Shitty Beatles
# Beatles Back2Back
# Fab Beatles
# Capital Beatles
# Them Beatles
# Norwegian Beatles
# Daft Beatles
# The Beatles Revival Band
# The Beatles Connection
# The Better Beatles
# The Wife-Beatles
# The Black Beatles
# Not The Beatles
# The Click Beatles

# %%
req['artists']
# Out:
# [{'id': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#   'type': 'Group',
#   'type-id': 'e431f5f6-b5d2-343d-8b36-72607fffb74b',
#   'score': 100,
#   'name': 'The Beatles',
#   'sort-name': 'Beatles, The',
#   'area': {'id': '9d5dd675-3cf4-4296-9e39-67865ebee758',
#    'type': 'Subdivision',
#    'type-id': 'fd3d44c5-80a1-3842-9745-2c4972d35afa',
#    'name': 'England',
#    'sort-name': 'England',
#    'life-span': {'ended': None}},
#   'begin-area': {'id': 'c249c30e-88ab-4b2f-a745-96a25bd7afee',
#    'type': 'City',
#    'type-id': '6fd8f29a-3d0a-32fc-980d-ea697b69da78',
#    'name': 'Liverpool',
#    'sort-name': 'Liverpool',
#    'life-span': {'ended': None}},
#   'isnis': ['0000000121707484'],
#   'life-span': {'begin': '1957-03', 'end': '1970-04-10', 'ended': True},
#   'aliases': [{'sort-name': 'Бітлз',
#     'name': 'Бітлз',
#     'locale': 'uk',
#     'type': None,
#     'primary': None,
#     'begin-date': None,
#     'end-date': None},
#    {'sort-name': '披頭四樂隊',
# ...

# %%
#req['artists'][0]

# %%
mbidid = req['artists'][0]['id']

# %%
artmbid = f'http://musicbrainz.org/ws/2/artist/{mbidid}?fmt=json'

# %%
reqmbid = requests.get(artmbid).json()

# %%
reqmbid
# Out:
# {'country': None,
#  'type': 'Group',
#  'gender-id': None,
#  'sort-name': 'Beatles, The',
#  'disambiguation': '',
#  'begin_area': {'name': 'Liverpool',
#   'disambiguation': '',
#   'sort-name': 'Liverpool',
#   'id': 'c249c30e-88ab-4b2f-a745-96a25bd7afee',
#   'type': None,
#   'iso-3166-2-codes': ['GB-LIV'],
#   'type-id': None},
#  'name': 'The Beatles',
#  'life-span': {'end': '1970-04-10', 'begin': '1957-03', 'ended': True},
#  'end_area': None,
#  'type-id': 'e431f5f6-b5d2-343d-8b36-72607fffb74b',
#  'gender': None,
#  'begin-area': {'name': 'Liverpool',
#   'disambiguation': '',
#   'sort-name': 'Liverpool',
#   'id': 'c249c30e-88ab-4b2f-a745-96a25bd7afee',
#   'type': None,
#   'iso-3166-2-codes': ['GB-LIV'],
#   'type-id': None},
#  'isnis': ['0000000121707484'],
#  'id': 'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#  'ipis': [],
#  'area': {'disambiguation': '',
#   'sort-name': 'England',
#   'id': '9d5dd675-3cf4-4296-9e39-67865ebee758',
#   'name': 'England',
# ...

# %% [markdown]
# ## Volvemos a probar

# %%
base = 'https://musicbrainz.org/ws/2/'

# %%
artista = 'The%20beatles'
artista = 'Luis+Ramiro'

# %%
artistq = f'http://musicbrainz.org/ws/2/artist/?query=artist:{artista}&fmt=json'

# %%
req = requests.get(artistq).json()

# %%
req.keys()
# Out:
# dict_keys(['created', 'count', 'offset', 'artists'])

# %%
req['created']
# Out:
# '2022-03-14T18:10:20.865Z'

# %%
req['count']
# Out:
# 1459

# %%
req['offset']
# Out:
# 0

# %%
req['artists'][0].keys()
# Out:
# dict_keys(['id', 'type', 'type-id', 'score', 'gender-id', 'name', 'sort-name', 'gender', 'life-span'])

# %%
req['artists']
# Out:
# [{'id': '797cc1b6-0f17-43a7-b379-f7ed0045fa5f',
#   'type': 'Person',
#   'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#   'score': 100,
#   'gender-id': '36d3d30a-839d-3eda-8cb3-29be4384e4a9',
#   'name': 'Luis Ramiro',
#   'sort-name': 'Ramiro, Luis',
#   'gender': 'male',
#   'life-span': {'ended': None}},
#  {'id': '2fa8695f-e311-41fd-934b-b0644a4f0657',
#   'score': 95,
#   'name': 'Ramiro',
#   'sort-name': 'Ramiro',
#   'disambiguation': 'participant in "El último adiós"',
#   'life-span': {'ended': None}},
#  {'id': 'd36dcc9b-34f8-40e7-a428-cf578bef92ef',
#   'type': 'Person',
#   'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#   'score': 94,
#   'name': 'Ramiro',
#   'sort-name': 'Ramiro',
#   'disambiguation': 'DJ, Label Owner, Spoken Word',
#   'life-span': {'ended': None}},
#  {'id': 'c14567d7-7648-4562-bdf0-91800be53263',
#   'type': 'Person',
#   'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#   'score': 94,
# ...

# %%
for r in req['artists']:
    #print(r['score'],type(r['score']))
    if r['score'] == 100:
        claves = list(r.keys())
        print (claves)
        for c in claves:
            print(c, r[c])
# Out:
# ['id', 'type', 'type-id', 'score', 'gender-id', 'name', 'sort-name', 'gender', 'life-span']
# id 797cc1b6-0f17-43a7-b379-f7ed0045fa5f
# type Person
# type-id b6e035f4-3ce9-331c-97df-83397230b0df
# score 100
# gender-id 36d3d30a-839d-3eda-8cb3-29be4384e4a9
# name Luis Ramiro
# sort-name Ramiro, Luis
# gender male
# life-span {'ended': None}

# %%
num = 0
genero = 'genero'
for r in req['artists'][0]['tags']:
    if r['count'] > num:
        num = r['count']
        genero = r['name']
genero

# %%
artists = pd.read_sql_query(f'''

SELECT * FROM artistas order by artist;

''',engine)

# %%
len(artists) /40
# Out:
# 60.175

# %%
artistssample = artists.sample(10)

# %%
artistssample.sample()
# Out:
#       id_art     artist  sexo   genero band  id_p
# 2372    1781  Will.I.Am  masc  hip hop    s    75

# %%
len(artists), artists.shape, max(artists.id_art)
# Out:
# (2407, (2407, 6), 2421)

# %% [markdown]
# ```python
#
# from pymongo import MongoClient
#
# # Create connection to MongoDB
# client = MongoClient('localhost', 27017)
# db = client['name_of_database']
# collection = db['name_of_collection']
#
# # Build a basic dictionary
# d = {'website': 'www.carrefax.com', 'author': 'Daniel Hoadley', 'colour': 'purple'}
#
# # Insert the dictionary into Mongo
# collection.insert(d)
#
# ```

# %%
client = MongoClient('localhost', 27017)
db = client['musicable']
collection = db['Discogs_artist']

# %%
dicc = {}
for i,r in artists.iterrows():
    time.sleep(1)
    artistq = f'http://musicbrainz.org/ws/2/artist/?query=artist:{r.artist}&fmt=json'
    reqart = requests.get(artistq).json()
    for rart in reqart['artists']:
        if rart['score'] == 100:
            claves = list(rart.keys())
            if 'country' in [c.lower() for c in claves]:
                collection.insert_one({r.artist:{'country': rart['country']}})
                #dicc[r.artist] = {'country': rart['country'] }
            elif 'area' in [c.lower() for c in claves]:
                collection.insert_one({r.artist:{'area': rart['area']['name'] }})
                #dicc[r.artist] = {'area': rart['area']['name'] }
            elif 'begin-area' in [c.lower() for c in claves]:
                collection.insert_one({r.artist:{'begin-area' : rart['begin-area']['name'] }})
                #dicc[r.artist] = {'begin-area' : rart['begin-area']['name'] }
            else:
                collection.insert_one({r.artist:{'claves':claves}})
                dicc[r.artist] = {'claves':claves}
    if i%40 == 0:
        print('done: ',i,r.artist )
    elif i == len(artists) - 1:
        print('total done IV')
# Out:
# done:  0 091
# done:  40 Alan Parsons
# done:  80 Amanita Suit
# done:  120 Antony and the Johnsons
# done:  160 Bailey Grey
# done:  200 Betagarri
# done:  240 Blake Shelton
# done:  280 Britney Spears
# done:  320 Cañaman
# done:  360 Chad Kroeger
# done:  400 Cindy Bullens/Louis St. Louis
# done:  440 Craig Morgan
# done:  480 David Bisbal
# done:  520 Die Antwoord
# done:  560 Doug Stone
# done:  600 El Arrebato
# done:  640 Emily Wells
# done:  680 Extremoduro
# done:  720 Foreigner
# done:  760 Gary Stewart
# done:  800 Gossip
# done:  840 Headcrash
# done:  880 Imogen Heap
# done:  920 Japan
# done:  960 Joan Jett
# done:  1000 Johnny Horton
# done:  1040 June Carter & Johnny Cash
# done:  1080 Kepa Junkera
# done:  1120 La Frontera
# done:  1160 Le Parody
# done:  1200 Live
# done:  1240 Los insoportables
# done:  1280 Luiz Bonfá
# done:  1320 Maria Arnal i Marcel Bagés
# done:  1360 Mathilda Plum Doucette Zappa
# done:  1400 Michael Gore Dean Pitchford
# done:  1440 Misfits
# ...

# %%
collect = db['artistas_dis']

# %%
dicc = {}
for i,r in artists.iterrows():
    time.sleep(1)
    artistq = f'http://musicbrainz.org/ws/2/artist/?query=artist:{r.artist}&fmt=json'
    reqart = requests.get(artistq).json()
    for rart in reqart['artists']:
        if rart['score'] == 100:
            collect.insert_one(rart)
    if i%40 == 0:
        print('done: ',i,r.artist )
    elif i == len(artists) - 1:
        print('total done IV')
# Out:
# done:  0 091
# done:  40 Alan Parsons
# done:  80 Amanita Suit
# done:  120 Antony and the Johnsons
# done:  160 Bailey Grey
# done:  200 Betagarri
# done:  240 Blake Shelton
# done:  280 Britney Spears
# done:  320 Cañaman
# done:  360 Chad Kroeger
# done:  400 Cindy Bullens/Louis St. Louis
# done:  440 Craig Morgan
# done:  480 David Bisbal
# done:  520 Die Antwoord
# done:  560 Doug Stone
# done:  600 El Arrebato
# done:  640 Emily Wells
# done:  680 Extremoduro
# done:  720 Foreigner
# done:  760 Gary Stewart
# done:  800 Gossip
# done:  840 Headcrash
# done:  880 Imogen Heap
# done:  920 Japan
# done:  960 Joan Jett
# done:  1000 Johnny Horton
# done:  1040 June Carter & Johnny Cash
# done:  1080 Kepa Junkera
# done:  1120 La Frontera
# done:  1160 Le Parody
# done:  1200 Live
# done:  1240 Los insoportables
# done:  1280 Luiz Bonfá
# done:  1320 Maria Arnal i Marcel Bagés
# done:  1360 Mathilda Plum Doucette Zappa
# done:  1400 Michael Gore Dean Pitchford
# done:  1440 Misfits
# ...
