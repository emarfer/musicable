# %%
import pandas as pd
import os
import sqlalchemy as alch
import dotenv
import datetime
import time

dotenv.load_dotenv()

import sys
sys.path.append('../src')
import apilast as als
import sqltools as sqt
import sqlalchemy as alch
import cleansing as cls
import scrodos as lio

# %%
passw = os.getenv("mysql")
dbName = "musicablecero"
connectionData = f"mysql+pymysql://root:{passw}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %%
esteruki = pd.read_csv('../output/esteruki.csv')

# %%
esteruki.head(5)
# Out:
#           uts           artist                           artist_mbid  \
# 0  1644410584      The Beatles  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# 1  1644410358  Franz Ferdinand  aa7a2827-f74b-473c-bd79-03d065835cf7
# 2  1644410134      Cat Stevens  e2345fdf-2be7-47c5-a6dd-be64353ad134
# 3  1644409823         Bon Jovi  5dcdb5eb-cb72-4e6e-9e63-b7bace604965
# 4  1644409580     Lana Del Rey  b7539c32-53e7-4908-bda3-81449c367da6
#
#                               album                            album_mbid  \
# 0                      Second Album                                   NaN
# 1                   Franz Ferdinand  1755aa40-6c51-4b27-82bd-bb3bb54f33f7
# 2             Tea for the Tillerman  01bc6011-0f7f-35aa-b2d3-9037963e6439
# 3                        New Jersey  00b74e25-4408-4d3d-8ce4-01d5b156048a
# 4  Chemtrails Over the Country Club  0084311d-5257-492f-a37a-1295ecc41011
#
#                title                            track_mbid  \
# ...

# %%
len(esteruki)//7000
# Out:
# 23

# %%
utss = []
for i,r in esteruki.iterrows():
    if i%7000 == 0:
        print(f'checking {i} of {len(esteruki)}')
    
    if sqt.checkuts(r.uts) == False:
        utss.append(r.uts)
# Out:
# checking 0 of 166566
# checking 7000 of 166566
# checking 14000 of 166566
# checking 21000 of 166566
# checking 28000 of 166566
# checking 35000 of 166566
# checking 42000 of 166566
# checking 49000 of 166566
# checking 56000 of 166566
# checking 63000 of 166566
# checking 70000 of 166566
# checking 77000 of 166566
# checking 84000 of 166566
# checking 91000 of 166566
# checking 98000 of 166566
# checking 105000 of 166566
# checking 112000 of 166566
# checking 119000 of 166566
# checking 126000 of 166566
# checking 133000 of 166566
# checking 140000 of 166566
# checking 147000 of 166566
# checking 154000 of 166566
# checking 161000 of 166566

# %%
print(utss)
# Out:
# [1640351615, 1440270788, 1440258326, 1440256767, 1440256492, 1440256211, 1440255392, 1440255145, 1440254926, 1440254750, 1440253709, 1440253511, 1440253256, 1440252999, 1440252714, 1440252462, 1440252023, 1440251852, 1440251659, 1440251512, 1440251049, 1440250874, 1440250679, 1440250522, 1440249891, 1440247637, 1440247431, 1395213246, 1379837052, 1371230196, 1362174241, 1361744804, 1361379362, 1361156672, 1357560580, 1357226151, 1353771165, 1353771164, 1353767727, 1350558726, 1343977854, 1343977183, 1343976980, 1343975785, 1343975441, 1343975171, 1343974658, 1343973992, 1343973788, 1343972580, 1343972228, 1343971959, 1343971283, 1343970619, 1343970384, 1343969170, 1343968857, 1343968558, 1341070889, 1334641841, 1329514662, 1329514303, 1327842128, 1327816038, 1322907259, 1322749035, 1319762218, 1319222434, 1319010151, 1318610469, 1318386663, 1318386517, 1318355153, 1318004253, 1316855861, 1316480605, 1315962322, 1315949472, 1315354840, 1314988250, 1314560099, 1314353817, 1314297711, 1
# ...

# %%
utsnoreg = esteruki[esteruki['uts'].isin(utss)]

# %%
utsnoreg.to_csv('../output/ustnoreg.csv',index=False)

# %%
utsnoreg.sample(5)
# Out:
#                uts       artist                           artist_mbid  \
# 146841  1313991526   John Mayer  144ef525-85e9-40c3-8335-02c32d0861f3
# 158848  1295638814  Extremoduro  f59163ba-1a7a-4349-b0fd-fb9582ebe333
# 161363  1293919788  PSC unkonwn                                   NaN
# 147197  1313784079   Duncan Dhu                                   NaN
# 146313  1314223074   John Mayer  144ef525-85e9-40c3-8335-02c32d0861f3
#
#                                      album album_mbid  \
# 146841     Live at Susquehanna Bank Center        NaN
# 158848                Yo, Minoría Absoluta        NaN
# 161363                                 PSC        NaN
# 147197            Coleccion 1985-1998 Cd 1        NaN
# 146313  Live at Music Hall of Williamsburg        NaN
#
#                                   title                            track_mbid  \
# 146841                       Crossroads  14bf923f-3cd8-3060-9751-10582d8947e3
# ...

# %%
utsnoreg[utsnoreg['track_mbid'].isna()==False]
# Out:
#                uts                 artist  \
# 62073   1440270788                Toundra
# 62103   1440258326               Galantis
# 62113   1440256767     Zugezogen Maskulin
# 62114   1440256492          Calvin Harris
# 62115   1440256211            Duke Dumont
# ...            ...                    ...
# 158862  1295637019  The Chemical Brothers
# 158864  1295636786             Toby Keith
# 158866  1295636442                Kortatu
# 158868  1295636285            The Beatles
# 158872  1295635684              The Verve
#
#                                  artist_mbid                  album  \
# 62073   68766d21-1668-4e06-b49d-e881446afc02                     IV
# 62103   a7229e38-bab7-48c1-9f35-9b4c49738b0f               Pharmacy
# 62113   5253c841-021b-4847-a80d-3821bc30bf0b           Alles brennt
# 62114   8dd98bdc-80ec-4e93-8509-2f46bafc09a7  How Deep Is Your Love
# 62115   6060d1bb-94f8-4863-89b9-425487f2f6b2                    EP1
# ...

# %%
utsnoreg.artist.value_counts().head(16) # + de 1 (29)
# Out:
# PSC unkonwn                     20
# John Mayer                      20
# Kathleen Edwards                18
# Extremoduro                      6
# John Mayer Trio                  5
# Duncan Dhu                       5
# Ska Covers                       5
# ÃûÕìÌ½¿ÂÄÏ                       4
# Sonata Arctica                   4
# Brian                            4
# La Fuga                          3
# Ana Belén;Joan Manuel Serrat     3
# The Beatles                      3
# 坂本龍一                             3
# Depeche Mode                     3
# Platero y tú                     3
# Name: artist, dtype: int64

# %%
art_tres = list(utsnoreg.artist.value_counts().head(16).keys())

# %%
utsnoreg[utsnoreg['artist'].isin(art_tres)]
# Out:
#                uts       artist artist_mbid album album_mbid  \
# 90938   1395213246   ÃûÕìÌ½¿ÂÄÏ         NaN   NaN        NaN
# 115243  1362174241   Ska Covers         NaN   NaN        NaN
# 116706  1361156672        Brian         NaN   NaN        NaN
# 121747  1357560580   Ska Covers         NaN   NaN        NaN
# 122439  1357226151        Brian         NaN   NaN        NaN
# ...            ...          ...         ...   ...        ...
# 161363  1293919788  PSC unkonwn         NaN   PSC        NaN
# 163215  1292860387  PSC unkonwn         NaN   PSC        NaN
# 163439  1292764109  PSC unkonwn         NaN   PSC        NaN
# 163441  1292763868  PSC unkonwn         NaN   PSC        NaN
# 163443  1292763524  PSC unkonwn         NaN   PSC        NaN
#
#                                   title track_mbid            fechahora
# 90938                   Time after time        NaN  2014-03-19 08:14:06
# 115243                 James Bond Theme        NaN  2013-03-01 22:44:01
# ...

# %%
os.listdir('../output/')
# Out:
# ['albums_genero.csv',
#  'esteruki.csv',
#  'generosdf.csv',
#  'jesterukicompleto.csv',
#  'prueba01_musicdf.csv',
#  'sinatxestercompleto.csv',
#  'ustnoreg.csv']

# %%
ester = pd.read_csv('../output/sinatxestercompleto.csv')

# %%
ester.head()
# Out:
#           uts           artist                           artist_mbid  \
# 0  1644410584      The Beatles  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# 1  1644410358  Franz Ferdinand  aa7a2827-f74b-473c-bd79-03d065835cf7
# 2  1644410134      Cat Stevens  e2345fdf-2be7-47c5-a6dd-be64353ad134
# 3  1644409823         Bon Jovi  5dcdb5eb-cb72-4e6e-9e63-b7bace604965
# 4  1644409580     Lana Del Rey  b7539c32-53e7-4908-bda3-81449c367da6
#
#                               album                            album_mbid  \
# 0                      Second Album                                   NaN
# 1                   Franz Ferdinand  1755aa40-6c51-4b27-82bd-bb3bb54f33f7
# 2             Tea for the Tillerman  01bc6011-0f7f-35aa-b2d3-9037963e6439
# 3                        New Jersey  00b74e25-4408-4d3d-8ce4-01d5b156048a
# 4  Chemtrails Over the Country Club  0084311d-5257-492f-a37a-1295ecc41011
#
#                title                            track_mbid
# ...

# %%
ester.uts.min()
# Out:
# 1420141487
