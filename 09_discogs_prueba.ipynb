# %%
import requests
from dotenv import load_dotenv
load_dotenv()
import os
import pandas as pd
import sqlalchemy as alch
import numpy as np
import sys
sys.path.append('src')
import apidiscogs as apd
import time

# %%
tokendis = os.getenv("discog")

# %%
passw = os.getenv("mysql")
dbName = "musicablecero"
connectionData = f"mysql+pymysql://root:{passw}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %%
albums = pd.read_sql_query(f"""
                   
                    select a.artist,b.album,b.id_alb from albums b left join artistas a on b.id_art = a.id_art;
                    """
                    , engine)

# %%
#select a.artist,b.album,b.id_alb from albums b left join artistas a on b.id_art = a.id_art;

# %%
albums.sample(3)
# Out:
#              artist                   album  id_alb
# 497           Queen                The Game     498
# 2774  George Strait  Chill of an Early Fall    2776
# 4024   Niña Pastori         Joyas Prestadas    4026

# %%
albumsprueba = albums.sample(20)

# %%
albumsprueba['art_url'] = albumsprueba.artist.replace(' ','+',regex=True)
albumsprueba['alb_url'] = albumsprueba.album.replace(' ','+',regex=True)

# %%
albumsprueba.head(3)

# %%
# lista = []
# for i,r in albumsprueba.iterrows():
#     dicc = {}
#     url = f'https://api.discogs.com/database/search?artist={r.art_url}&release_title={r.alb_url}&token={tokendis}'
#     req = requests.get(url).json()
#     if req['results'] == []:
        
#         dicc['id_alb'] = r.id_alb
#         dicc['gen'] = np.nan
#         dicc['genres'] = np.nan
#         dicc['subgenres'] = np.nan
#         lista.append(dicc)

#     else:
#         genero = req['results'][0]['genre']
#         subgenero = req['results'][0]['style']
#         dicc['id_alb'] = r.id_alb
#         dicc['gen'] = req['results'][0]['genre'][0]
#         dicc['genres'] = req['results'][0]['genre']
#         dicc['subgenres'] = req['results'][0]['style']
#         lista.append(dicc)

# %%
albums['art_url'] = albums.artist.replace(' ','+',regex=True)
albums['alb_url'] = albums.album.replace(' ','+',regex=True)

# %%
albums.head(5)
# Out:
#             artist                  album  id_alb          art_url  \
# 0  Siniestro Total          Made in Japan       1  Siniestro+Total
# 1     Platero y tú   Hay Poco Rock & Roll       2     Platero+y+tú
# 2       Pablo Ager   Durmiendo En Azoteas       3       Pablo+Ager
# 3      Luis Ramiro  Castigado En El Cielo       4      Luis+Ramiro
# 4   Niños Mutantes               Florecer       5   Niños+Mutantes
#
#                  alb_url
# 0          Made+in+Japan
# 1   Hay+Poco+Rock+&+Roll
# 2   Durmiendo+En+Azoteas
# 3  Castigado+En+El+Cielo
# 4               Florecer

# %%
albums.shape[0]/60/60
# Out:
# 1.1830555555555555

# %%
60*60
# Out:
# 3600

# %%
#probando = apd.generosdiscog(albumsprueba,albumsprueba.art_url,albumsprueba.alb_url,albumsprueba.id_alb)
lista = []
a=0
for i,r in albums.iterrows():
    
    lista.append(apd.generosdiscog(r.art_url,r.alb_url,r.id_alb))
    time.sleep(1)
# Out:
# 10:('Luis+Ramiro', 'Dramas+Y+Caballeros') hecho
# 20:('Mägo+de+Oz', 'La+Leyenda+De+La+Mancha') hecho
# 30:('Mägo+de+Oz', 'Gaia') hecho
# 40:('The+Chemical+Brothers', 'Surrender') hecho
# 50:('Santana', 'Ultimate+Santana') hecho
# 60:('Bon+Jovi', 'Cross+Road') hecho
# 70:('Varios+Artistas', 'BSO+Dangerous+Minds') hecho
# 80:('Queen', 'A+Kind+of+Magic') hecho
# 90:('The+Bangles', 'Different+Light') hecho
# 100:('The+Beatles', 'From+Me+to+You') hecho
# 110:('The+Corrs', 'Talk+On+Corners') hecho
# 120:('Rocky+Sharpe+&+The+Replays', 'Rama+Lama') hecho
# 130:('Europe', 'The+Final+Countdown') hecho
# 140:('Blind+Guardian', 'Imaginations+From+the+Other+Side') hecho
# 150:('Celtas+Cortos', 'Tranquilo+majete') hecho
# 160:('Alaska', 'Delirios+de+Grandeza') hecho
# 170:('Mecano', 'Mecano') hecho
# 180:('George+Harrison', 'Cloud+Nine') hecho
# 190:('Oasis', 'Whatever') hecho
# 200:('Dire+Straits', 'Dire+Straits') hecho
# 210:('Bob+Marley+&+The+Wailers', 'Songs+of+Freedom') hecho
# 220:('Marea', 'Revolcón') hecho
# 230:('La+Guardia', 'Vámonos') hecho
# 240:('La+Oreja+de+Van+Gogh', 'Dile+al+sol') hecho
# 250:('Hombres+G', 'Peligrosamente+Juntos') hecho
# 260:('Matchbox+Twenty', 'Yourself+or+Someone+Like+You') hecho
# 270:('Fito+&+Fitipaldis', 'Vivo...+Para+Contarlo') hecho
# 280:('The+Beatles', "A+Hard+Day's+Night") hecho
# 290:('The+Who', 'My+Generation') hecho
# 300:('Joaquín+Sabina', '19+Días+y+500+Noches') hecho
# 310:('Metallica', 'Metallica') hecho
# 320:('Matchbox+Twenty', 'Exile+On+Mainstream') hecho
# 330:('Joaquín+Sabina', 'Física+y+Química') hecho
# 340:('Ozzy+Osbourne', 'Ozzmosis') hecho
# 350:('Un+Pingüino+En+Mi+Ascensor', 'La+sangre+y+la+televisión') hecho
# 360:('Billie+Myers', 'Growing,+Pains') hecho
# 370:('Sonata+Arctica', 'Silence') hecho
# 380:('Richard+Ashcroft', 'Alone+With+Everybody') hecho
# 390:('Europe', 'Out+Of+This+World') hecho
# 400:('Lucie+Silvas', 'Breathe+In') hecho
# 410:('The+Cure', 'Wish') hecho
# 420:('Amaral', 'Amaral') hecho
# 430:('Rosana', 'Rosana') hecho
# 440:('Toto', 'Toto+IV') hecho
# 450:('Madness', 'Absolutely') hecho
# 460:('The+Alan+Parsons+Project', 'Gaudi') hecho
# 470:('Autograph', 'Sign+in+Please') hecho
# 480:('Warrant', "Cherry+Pie+all+the+Hitz+'n'+More") hecho
# 490:('Night+Ranger', 'Midnight+Madness') hecho
# 500:('The+Brian+Setzer+Orchestra', 'Vavoom!') hecho
# 510:('Seguridad+Social', 'Furia+latina') hecho
# 520:('Toni+Braxton', 'Secrets') hecho
# 530:('M+People', 'Elegant+Slumming') hecho
# 540:('The+Baseballs', 'Strike!+Back') hecho
# 550:('Gigatron', 'Mar+De+Cuernos') hecho
# 560:('Bebe', 'Pafuera+Telarañas') hecho
# 570:('Pabellón+Psiquiátrico', 'La+Primera+En+La+Frente') hecho
# 580:('Ricky+Martin', 'A+Medio+Vivir') hecho
# 590:('Bad+English', 'Love+Songs') hecho
# 600:('Nirvana', 'Nevermind') hecho
# 610:('The+Searchers', 'Meet+The+Searchers') hecho
# 620:('Amistades+Peligrosas', 'La+profecía') hecho
# 630:('Quiet+Riot', 'Metal+Health') hecho
# 640:('Texas', 'White+On+Blonde') hecho
# 650:('10cc', 'The+Original+Soundtrack') hecho
# 660:('Luis+Eduardo+Aute', 'Alma') hecho
# 670:('Angra', 'Angels+Cry') hecho
# 680:('Taylor+Swift', 'Speak+Now') hecho
# 690:('Bryan+Adams', "18+'Til+I+Die") hecho
# 700:('Kid+Rock', 'Rock+N+Roll+Jesus') hecho
# 710:('Kylie+Minogue', 'Fever') hecho
# 720:('Marvin+Gaye+&+Tammi+Terrell', 'United') hecho
# 730:('Creedence+Clearwater+Revival', 'More+Creedence+Gold') hecho
# 740:('DJ+Shadow', 'The+Private+Press') hecho
# 750:('Stromae', 'Cheese') hecho
# 760:('The+Calling', 'Camino+Palmero') hecho
# 770:('Toploader', "Onka's+Big+Moka") hecho
# 780:('Diamanda+Galás', 'Defixiones,+Will+and+Testament') hecho
# 790:('Bon+Jovi', 'Have+A+Nice+Day') hecho
# 800:('Céline+Dion', 'The+Colour+of+My+Love') hecho
# 810:('Siniestro+Total', 'Ante+Todo,+Mucha+Calma') hecho
# 820:('Sasha+Sokol', 'Por+Un+Amor') hecho
# 830:('Santana', 'Guitar+Heaven:+The+Greatest+Guitar+Classics+Of+All+Time') hecho
# 840:('Waylon+Jennings', "The+Ramblin'+Man") hecho
# 850:('The+Isley+Brothers', '3+3') hecho
# 860:('Pedro+Guerra', 'Tan+Cerca+De+Mí') hecho
# 870:('Los+Nikis', 'Marines+a+pleno+sol') hecho
# 880:('Lalo+Rodriguez', 'Aquí+Está+La+Salsa') hecho
# 890:('Jay-Z', 'The+Blueprint+3') hecho
# 900:('Supertramp', 'Breakfast+in+America') hecho
# 910:('James+Taylor', 'Gorilla') hecho
# 920:('Shivaree', 'I+Oughtta+Give+You+A+Shot+In+The+Head+For+Making+Me+Live+In+This+Dump') hecho
# 930:('The+Kinks', 'Phobia') hecho
# 940:('The+Beatles', 'Hey+Jude') hecho
# 950:('AC/DC', 'Highway+to+Hell') hecho
# 960:('Fritanga', 'Cuidado+que+quema') hecho
# 970:('Khaled', 'Sahra') hecho
# 980:('Sonata+Arctica', "Don't+Say+A+Word") hecho
# 990:('Brooks+&+Dunn', 'The+Essential+Brooks+&+Dunn') hecho
# 1000:('Toby+Keith', 'White+Trash+With+Money') hecho
# 1010:('Kellie+Pickler', 'Kellie+Pickler') hecho
# 1020:('Wade+Hayes', 'Old+Enough+To+Know+Better') hecho
# 1030:('U2', 'The+Best+Of+1980-1990') hecho
# 1040:('Los+Piojos', 'Verde+paisaje+del+infierno') hecho
# 1050:('Varios+Artistas', 'Punk+Goes+Pop+Vol.+2') hecho
# 1060:('Fito+&+Fitipaldis', 'Un+Camino+De+Piedras') hecho
# 1070:('Arcade+Fire', 'Arcade+Fire') hecho
# 1080:('Amy+Dalley', "Love's+Really+Got+An+Attitude") hecho
# 1090:('Doug+Supernaw', 'Red+and+Rio+Grande') hecho
# 1100:('Garth+Brooks', 'The+Lost+Sessions') hecho
# 1110:('Julie+Roberts', 'Men+&+Mascara') hecho
# 1120:('Faith+Hill', 'Breathe') hecho
# 1130:('Mark+Chesnutt', 'Almost+Goodbye') hecho
# 1140:('Reba+McEntire', 'Starting+Over') hecho
# 1150:('Carolyn+Dawn+Johnson', 'Room+with+a+View') hecho
# 1160:('The+Beatles', 'Live+at+the+BBC') hecho
# 1170:('Blue+Öyster+Cult', 'Fire+of+Unknown+Origin') hecho
# 1180:('Train', 'Alive+at+Last') hecho
# 1190:('Alan+Jackson', 'When+Somebody+Loves+You') hecho
# 1200:('Joni+Mitchell', 'Blue') hecho
# 1210:('Tori+Amos', 'Y+Kant+Tori+Read') hecho
# 1220:('Mark+Wills', 'Wish+You+Were+Here') hecho
# 1230:('Los+Secretos', 'Continuará') hecho
# 1240:('Brooks+&+Dunn', 'Hillbilly+Deluxe') hecho
# 1250:('Cledus+T.+Judd', 'Bipolar+and+Proud') hecho
# 1260:('Kenny+Chesney', 'The+Road+and+the+Radio') hecho
# 1270:('Londonbeat', 'In+the+Blood') hecho
# 1280:('I+Am+Kloot', 'Natural+History') hecho
# 1290:('Ronnie+Milsap', 'Lost+in+the+Fifties+Tonight') hecho
# 1300:('Big+&+Rich', "Comin'+to+Your+City") hecho
# 1310:('Toby+Keith', 'Toby+Keith') hecho
# 1320:('Dolly+Parton', 'Rhinestone') hecho
# 1330:('AC/DC', 'Ballbreaker') hecho
# 1340:('James+Brown', 'Sex+Machine') hecho
# 1350:("The+B-52's", 'Cosmic+Thing') hecho
# 1360:('Annie+Lennox', 'Medusa') hecho
# 1370:('Gipsy+Kings', 'Gipsy+Kings') hecho
# 1380:('Sr.+Chinarro', 'El+Mundo+Según') hecho
# 1390:('Regina+Spektor', 'Begin+to+Hope') hecho
# 1400:('Standstill', 'Adelante+Bonaparte+-+III.el+corazón+de+B.+despierta') hecho
# 1410:('The+Mighty+Mighty+Bosstones', "Where'd+You+Go?") hecho
# 1420:('Los+Chichos', 'Ni+más+ni+menos') hecho
# 1430:('Kid+Rock', 'Cocky') hecho
# 1440:('Los+Rodríguez', 'Buena+Suerte') hecho
# 1450:('Rick+Astley', 'Whenever+You+Need+Somebody') hecho
# 1460:('Red+Hot+Chili+Peppers', 'Californication') hecho
# 1470:('Skunk+Anansie', "You'll+Follow+Me+Down") hecho
# 1480:('Jason+Matthews', "That's+What+Mamas+Do") hecho
# 1490:('George+Michael', 'Faith') hecho
# 1500:('Danza+Invisible', 'A+tu+alcance') hecho
# 1510:('Café+Tacvba', 'Cuatro+Caminos') hecho
# 1520:('No+Doubt', 'Rock+Steady') hecho
# 1530:('Los+Suaves', 'Maldita+sea+mi+suerte') hecho
# 1540:('Oasis', 'The+Early+Years') hecho
# 1550:('Ramones', 'Road+To+Ruin') hecho
# 1560:('Kepa+Junkera', 'Etxea') hecho
# 1570:('Yes', 'Fragile') hecho
# 1580:('This+Mortal+Coil', "It'll+End+in+Tears") hecho
# 1590:('Boyzone', 'By+Request') hecho
# 1600:('Barón+Rojo', 'Volumen+Brutal') hecho
# 1610:('Daniela+Romo', 'Amor+Prohibido') hecho
# 1620:('Harry+Belafonte', 'Calypso') hecho
# 1630:('Amistades+Peligrosas', 'Relatos+de+una+intriga') hecho
# 1640:('Tracy+Byrd', 'Ten+Rounds') hecho
# 1650:('Lynn+Anderson', 'What+a+Man+My+Man+Is') hecho
# 1660:('Vanilla+Ice', 'To+The+Extreme') hecho
# 1670:('Gloria+Trevi', 'Tu+ángel+de+la+guarda') hecho
# 1680:('Björk', 'Drawing+Restraint+9') hecho
# 1690:('Bryan+Adams,+Rod+Stewart,+Sting', 'The+Three+Musketeers') hecho
# 1700:('Nino+Bravo', 'Un+beso+y+una+flor') hecho
# 1710:('The+Doors', 'The+Doors') hecho
# 1720:('Nina+Simone', 'Here+Comes+the+Sun') hecho
# 1730:('Bon+Jovi', 'One+Wild+Night') hecho
# 1740:('Anton+Leuba', 'Under+Construction') hecho
# 1750:('Manolo+Escobar', 'Grandes+Éxitos') hecho
# 1760:('Los+Ronaldos', 'Guárdalo+Con+Amor') hecho
# 1770:('Rulo+y+la+contrabanda', 'Señales+de+humo') hecho
# 1780:('Beth+Ditto', 'EP') hecho
# 1790:('Mala+Rodríguez', 'Lujo+Ibérico') hecho
# 1800:('Petula+Clark', 'Les+Plus+Grands+Succès+De+Petula+Clark') hecho
# 1810:('Helloween', 'The+Dark+Ride') hecho
# 1820:('Diana+King', 'Bad+boys+OST') hecho
# 1830:('Wisin+&+Yandel', 'Caribe+2009') hecho
# 1840:('Ellen+Allien', 'Thrills') hecho
# 1850:('David+Bowie', '"Heroes"') hecho
# 1860:('John+Denver', 'Back+Home+Again') hecho
# 1870:('Lebo+M', 'Rhythm+of+the+Pride+Lands') hecho
# 1880:('Patti+Smith', 'Horses') hecho
# 1890:('Van+Morrison', 'Into+the+Music') hecho
# 1900:('Less+Than+Jake', 'G-Man+Training+Target') hecho
# 1910:('Blur', 'Modern+Life+Is+Rubbish') hecho
# 1920:('Orishas', 'A+Lo+Cubano') hecho
# 1930:('La+Prohibida', 'Señor+Kubrick,+¿Qué+haría+usted?') hecho
# 1940:('Jennifer+Lopez', 'This+Is+Me...+Then') hecho
# 1950:('McNamara', 'Rockstation') hecho
# 1960:('Chris+Daughtry', 'Daughtry') hecho
# 1970:('Queen', 'Innuendo') hecho
# 1980:('The+Be+Good+Tanyas', 'Chinatown') hecho
# 1990:('Édith+Piaf', 'La+vie+en+rose') hecho
# 2000:('Patti+Rothberg', 'Beverly+Hills+Ninja') hecho
# 2010:('Nicolas+Jaar', 'Space+Is+Only+Noise') hecho
# 2020:('Huey+Lewis+and+the+News', 'Fore!') hecho
# 2030:('Zapato+Veloz', 'A+toda+máquina') hecho
# 2040:('El+Fary', 'El+Fary') hecho
# 2050:('Smash+Mouth', 'Shrek') hecho
# 2060:('Eric+Heatherly', 'Swimming+in+Champagne') hecho
# 2070:('Arctic+Monkeys', 'Suck+It+And+See') hecho
# 2080:('Desechos', 'Cuando+Es+Mañana') hecho
# 2090:('The+Cramps', 'A+Date+With+Elvis') hecho
# 2100:('Joni+Mitchell', 'Mingus') hecho
# 2110:('Santana', 'Havana+Moon') hecho
# 2120:('Blue+Öyster+Cult', 'Imaginos') hecho
# 2130:('Simple+Minds', "Don't+You+(Forget+About+Me)") hecho
# 2140:('Dierks+Bentley', 'Dierks+Bentley') hecho
# 2150:('La+Cabra+Mecánica', 'Carne+de+canción') hecho
# 2160:('Oasis', 'Heathen+Chemistry') hecho
# 2170:('Randy+Travis', 'Always+&+Forever') hecho
# 2180:('Tamara', 'A+por+ti') hecho
# 2190:('Santana', 'Caravansarai') hecho
# 2200:('Patti+Smith', 'Gone+Again') hecho
# 2210:('Varios+Artistas', 'Concierto+para+40+T+V') hecho
# 2220:('Jennifer+Lopez', 'On+the+6') hecho
# 2230:('Marta+Méndez', 'Marta+Méndez') hecho
# 2240:('Drum+Theater', 'Everyman') hecho
# 2250:('Santana', 'Aniversario') hecho
# 2260:('Bob+Dylan', 'Concert+at+Philharmonic+Hall') hecho
# 2270:('Kate+Bush', 'Hounds+of+Love') hecho
# 2280:('Trace+Adkins', 'Dangerous+Man') hecho
# 2290:('Oasis', 'Be+Here+Now') hecho
# 2300:('The+Outfield', 'Play+Deep') hecho
# 2310:('Bob+Dylan', 'Blonde+on+Blonde') hecho
# 2320:('The+Veer+Union', 'Against+the+Grain') hecho
# 2330:('Varios+Artistas', 'The+Beauty+In+Ugly+(Ugly+Betty+Version)') hecho
# 2340:('Counting+Crows', 'This+Desert+Life') hecho
# 2350:('Oasis', 'Definitely+Maybe') hecho
# 2360:('Joni+Mitchell', 'Dog+Eat+Dog') hecho
# 2370:('David+Bowie', 'Bowie+at+the+Beeb') hecho
# 2380:('Santana', 'All+That+I+Am') hecho
# 2390:('Patti+Smith', 'Exodus') hecho
# 2400:('Arcadia', 'So+Red+the+Rose') hecho
# 2410:('El+Chivi', 'Radikal') hecho
# 2420:('Porter+Wagoner+&+Dolly+Parton', 'Just+Between+You+and+Me') hecho
# 2430:('Thompson+Twins', 'Set') hecho
# 2440:('The+Kinks', 'Preservation+Act+1') hecho
# 2450:('PJ+Harvey', 'Stories+from+the+City,+Stories+from+the+Sea') hecho
# 2460:('George+Harrison', 'Living+in+the+Material+World') hecho
# 2470:('Bob+Dylan', 'Good+as+I+Been+to+You') hecho
# 2480:('Blue+Öyster+Cult', "A+Long+Day's+Night") hecho
# 2490:('Flobots', 'Survival+Story') hecho
# 2500:('John+Michael+Montgomery', 'What+I+Do+the+Best') hecho
# 2510:('Duncan+Dhu', 'Colección+1985-1998') hecho
# 2520:('Renée', 'The+future+none+can+see') hecho
# 2530:('George+Harrison', 'Somewhere+in+England') hecho
# 2540:('Joni+Mitchell', "Don+Juan's+Reckless+Daughter") hecho
# 2550:('Crystal+Castles', 'Crimewave') hecho
# 2560:('Jason+Mraz', 'Tonight,+Not+Again:+Live+At+The+Eagles+Ballroom') hecho
# 2570:('Samantha+Fox', 'I+Wanna+Have+Some+Fun') hecho
# 2580:('Raimundo+Amador', 'Un+Okupa+En+Tu+Corazón') hecho
# 2590:('Melon+Diesel', 'La+cuesta+de+Mister+Bond') hecho
# 2600:('Robin+S', 'Show+Me+Love') hecho
# 2610:('Massive+Attack', 'Heligoland') hecho
# 2620:('Daft+Punk', 'Human+After+All') hecho
# 2630:('Tom+Petty', 'Storytellers') hecho
# 2640:('Rosendo', 'Veo,+veo...+Mamoneo!!') hecho
# 2650:('La+Pegatina', 'Xapomelön') hecho
# 2660:('Manifa', 'Manifa,+tocando+los+cojones+en+directo') hecho
# 2670:('Brynn+Marie', 'Start+Now') hecho
# 2680:('John+Mayer', 'Inside+Wants+Out') hecho
# 2690:('Barbara+Fairchild', 'Classic+Country') hecho
# 2700:('INXS', 'Welcome+To+Wherever+You+Are') hecho
# 2710:('The+Who', 'Tommy') hecho
# 2720:('Alejandro+Sanz', 'Más') hecho
# 2730:('SHeDAISY', "Fortuneteller's+Melody") hecho
# 2740:('The+Bet', 'Facing+Fate') hecho
# 2750:('Duke+Ellington', 'Ellington+At+Newport') hecho
# 2760:('David+Lee+Roth', 'Sonrisa+Salvaje') hecho
# 2770:('Nina+Simone', 'Wild+is+the+Wind') hecho
# 2780:('El+Fary', 'Menudo+Es+El+Fary') hecho
# 2790:('The+Zombies', 'Odessey+&+Oracle') hecho
# 2800:('La+Vela+Puerca', 'La+Vela+Puerca') hecho
# 2810:('Glen+Campbell', 'Gentle+On+My+Mind') hecho
# 2820:('Varios+Artistas', 'Substitution+Mass+Confusion:+A+Tribute+to+The+Cars') hecho
# 2830:('Nicolette+Larson,+Jeff+Beck,+Terry+Bozzio+&+Tony+Hymas', 'Twins') hecho
# 2840:('Led+Zeppelin', 'Led+Zeppelin+II') hecho
# 2850:('Katie+Noonan', 'Blackbird') hecho
# 2860:("Shakin'+Stevens", "The+Bop+Won't+Stop") hecho
# 2870:('Santana', 'Carlos+Santana+&+Buddy+Miles!+Live!') hecho
# 2880:('J.B.O.', 'Laut') hecho
# 2890:('Paul+Doucette', 'Shredderman+Rules') hecho
# 2900:('Pimpinela', 'Mi+Historia') hecho
# 2910:('David+Bowie', 'Station+to+Station') hecho
# 2920:('Red+Hot+Chili+Peppers', 'Coneheads:+Music+from+the+Motion+Picture+Soundtrack') hecho
# 2930:('Almodóvar+&+McNamara', '¡cómo+está+el+servicio...+de+señoras!') hecho
# 2940:('Timi+Yuro', 'Hurt') hecho
# 2950:('New+York+Dolls', 'New+York+Dolls') hecho
# 2960:('Whitney+Houston', "I'm+Your+Baby+Tonight") hecho
# 2970:('Ryan+Paris', 'Dolce+vita') hecho
# 2980:('Emilio+Aragón', 'Te+huelen+los+pies') hecho
# 2990:('Bruce+Springsteen', 'The+Rising') hecho
# 3000:('Sonic+Youth', 'Sister') hecho
# 3010:('Allegro', 'Someone+Else') hecho
# 3020:('Putilatex', 'Domund') hecho
# 3030:('Ana+Torroja', 'Puntos+cardinales') hecho
# 3040:('Beastie+Boys', "Body+Movin'") hecho
# 3050:('The+Cure', 'Disintegration') hecho
# 3060:('Nick+Cave+&+The+Bad+Seeds', 'Abattoir+Blues/The+Lyre+Of+Orpheus') hecho
# 3070:('Lauryn+Hill', 'The+Miseducation+of+Lauryn+Hill') hecho
# 3080:('Limp+Bizkit', 'Chocolate+Starfish+and+the+Hot+Dog+Flavored+Water') hecho
# error: 'results', {'message': 'You are making requests too quickly.'}, id = 3081
# 3090:('Morrissey', 'Ringleader+of+the+Tormentors') hecho
# 3100:('Michael+Jackson', 'Got+To+Be+There') hecho
# 3110:('Joan+Jett', 'Bad+Reputation') hecho
# 3120:('Jason+Mraz', 'Love+Is+A+Four+Letter+Word') hecho
# 3130:('Billie+Holiday', 'Lady+In+Satin') hecho
# 3140:('Dolly+Parton', 'Those+Were+The+Days') hecho
# 3150:('Matchbox+Twenty', 'North') hecho
# 3160:('Black+Eyed+Peas', 'Monkey+Business') hecho
# 3170:('Macaco', 'El+murmullo+del+fuego') hecho
# 3180:('Theatre+of+Tragedy', 'Aégis') hecho
# 3190:('Depeche+Mode', 'Construction+Time+Again') hecho
# 3200:('The+Angels', "My+Boyfriend's+Back") hecho
# 3210:('Hinder', 'Extreme+Behavior') hecho
# 3220:('The+Cure', 'Seventeen+Seconds') hecho
# 3230:('Quique+González', 'Salitre+48') hecho
# 3240:('Mägo+de+Oz', 'Rarezas') hecho
# 3250:('Mägo+de+Oz', 'Belfast') hecho
# 3260:('Damien+Rice', '9') hecho
# 3270:('The+Asteroids+Galaxy+Tour', 'Out+of+Frequency') hecho
# 3280:('Bon+Iver', 'Bon+Iver') hecho
# 3290:('José+González', 'In+Our+Nature') hecho
# 3300:('Iván+Ferreiro', 'Canciones+para+el+tiempo+y+la+distancia') hecho
# 3310:('Joan+Manuel+Serrat', 'La+Paloma') hecho
# 3320:('Le+Tigre', 'Feminist+Sweepstakes') hecho
# 3330:('Christina+Rosenvinge', 'La+Joven+Dolores') hecho
# 3340:('Maga', 'A+la+Hora+del+Sol') hecho
# 3350:('Tontxu', 'Corazón+De+Mudanza') hecho
# 3360:('Love+of+Lesbian', 'Maniobras+de+escapismo') hecho
# 3370:('Morrissey', 'You+Are+The+Quarry') hecho
# 3380:('Japan', 'Gentlemen+Take+Polaroids') hecho
# 3390:('Yurena', 'Go') hecho
# 3400:('Carlos+Siles', 'Cuántas+Veces+Habré+Intentado+Que+Juegues+Conmigo') hecho
# 3410:('Miguel+Bosé', 'Los+chicos+no+lloran') hecho
# 3420:('La+Llave+De+Allen', 'Como+ratones') hecho
# 3430:('Rebeca+Jiménez', 'Todo+Llegará') hecho
# 3440:('Comalcool', 'Super+Extra+Plus') hecho
# 3450:('Lori+Meyers', 'Impronta') hecho
# 3460:('David+Santisteban', 'Las+Chicas+Al+Poder') hecho
# 3470:('Chimo+Bayo', 'Así+me+gusta+a+mí') hecho
# 3480:('Carlos+Vives', 'Clásicos+de+la+Provincia') hecho
# 3490:('David+Bowie', 'The+Next+Day') hecho
# 3500:('Ariel+Rot', 'La+Huesuda') hecho
# error: 'results', {'message': 'You are making requests too quickly.'}, id = 3501
# 3510:('Carlos+Chaouen', 'Universo+Abierto') hecho
# 3520:('Amanita+Suit', 'Seguiremos+Caminando') hecho
# 3530:('Tom+Waits', 'Swordfishtrombones') hecho
# 3540:('Underworld', 'Second+Toughest+in+the+Infants') hecho
# 3550:('El+Columpio+Asesino', 'Diamantes') hecho
# 3560:('Quique+González', 'Concierto+en+Radio+3') hecho
# 3570:('NACH', 'Los+Viajes+Inmóviles') hecho
# 3580:('Cyndi+Lauper', "She's+So+Unusual:+A+30th+Anniversary+Celebration") hecho
# 3590:('Cornershop', 'When+I+Was+Born+for+the+7th+Time') hecho
# 3600:('Will+Smith', 'Greatest+Hits') hecho
# 3610:('Siouxsie+and+the+Banshees', 'The+Scream') hecho
# 3620:('Manos+De+Topo', 'Caminitos+del+deseo') hecho
# 3630:('Leonard+Cohen', 'Popular+Problems') hecho
# 3640:('Pearl+Jam', 'Ten') hecho
# 3650:('Chic', 'Risqué') hecho
# 3660:('Tahúres+Zurdos', 'Tahuría') hecho
# 3670:('The+Vines', 'Highly+Evolved') hecho
# 3680:('The+Horrors', 'Strange+House') hecho
# 3690:('Sufjan+Stevens', 'Carrie+&+Lowell') hecho
# 3700:('Grant+Lee+Buffalo', 'Fuzzy') hecho
# 3710:('Pavement', 'Slanted+and+Enchanted') hecho
# 3720:('Dr.+John,+the+Night+Tripper', 'Gris-Gris') hecho
# 3730:('Saint+Etienne', 'Foxbase+Alpha') hecho
# 3740:('Florence+++the+Machine', 'Ceremonials') hecho
# 3750:('PJ+Harvey', 'Dry+&+Demonstration') hecho
# 3760:('Paula+Cole', 'This+Fire') hecho
# 3770:('Buika', 'Vivir+sin+miedo') hecho
# 3780:('Sleater-Kinney', 'No+Cities+To+Love') hecho
# 3790:('Gillian+Welch', 'Time+(The+Revelator)') hecho
# 3800:('Sunflower+Bean', 'Show+Me+Your+Seven+Secrets') hecho
# 3810:('Small+Faces', "Ogden's+Nut+Gone+Flake") hecho
# 3820:('M.I.A.', 'MAYA') hecho
# 3830:('Ray+Charles', 'The+Genius+Of+Ray+Charles') hecho
# 3840:('Emma+Pollock', 'In+Search+Of+Harperfield') hecho
# 3850:('Lykke+Li', 'Wounded+Rhymes') hecho
# 3860:('Fangoria', 'Naturaleza+Muerta') hecho
# 3870:('Love+of+Lesbian', 'El+Poeta+Halley') hecho
# 3880:('Emmy+The+Great', 'Virtue') hecho
# 3890:('Lacuna+Coil', 'Unleashed+Memories') hecho
# 3900:('Julianna+Barwick', 'Will') hecho
# 3910:('Neu!', 'Neu!') hecho
# 3920:('Jessy+Lanza', 'Oh+No') hecho
# 3930:('Nick+Cave+&+The+Bad+Seeds', 'Skeleton+Tree') hecho
# 3940:('RuPaul', 'Born+Naked') hecho
# 3950:('Gossip', "That's+Not+What+I+Heard") hecho
# 3960:('The+Sweet+Release+of+Death', 'The+Sweet+Release+of+Death') hecho
# 3970:('Noveller', 'Glacial+Glow') hecho
# 3980:('Jain', 'Zanaka') hecho
# 3990:('Laura+Marling', 'Semper+Femina') hecho
# 4000:('The+xx', 'I+See+You') hecho
# 4010:('Najwajean', 'No+Blood') hecho
# 4020:('Dolly+Parton', 'All+I+Can+Do') hecho
# 4030:('Shakira', 'El+Dorado') hecho
# 4040:('Lana+Del+Rey', 'Lust+For+Life') hecho
# 4050:('Miriam+Makeba', 'Makeba+Sings!') hecho
# 4060:('Vainica+Doble', 'Heliotropo') hecho
# 4070:('Tori+Amos', 'Native+Invader') hecho
# 4080:('Charlotte+Gainsbourg', 'Rest') hecho
# 4090:('Florence+++the+Machine', 'High+as+Hope') hecho
# 4100:('Gigatron', 'Los+Dioses+Han+Llegado') hecho
# 4110:('SOAK', 'Estado+de+Sitio') hecho
# 4120:('Vetusta+Morla', 'Los+ríos+de+Alice') hecho
# 4130:('Varios+Artistas', 'Deprisa,+Deprisa+(Banda+Sonora+De+La+Película+Del+Mismo+Título)') hecho
# 4140:('La+Maravillosa+Orquesta+del+Alcohol', 'Salvavida+(De+las+balas+perdidas)') hecho
# 4150:('Ghoti+Hook', "Songs+We+Didn't+Write") hecho
# 4160:('Less+Than+Jake', 'Scream+2') hecho
# 4170:('Kygo', 'Firestone') hecho
# 4180:('Seinabo+Sey', 'Pretend') hecho
# 4190:('Phoebe+Bridgers', 'Punisher') hecho
# 4200:('One+Direction', 'Take+Me+Home') hecho
# 4210:('Lana+Del+Rey', 'Chemtrails+Over+the+Country+Club') hecho
# 4220:('Bunbury', 'Radical+sonora') hecho
# 4230:('La+Maravillosa+Orquesta+del+Alcohol', 'No+Easy+Road') hecho
# 4240:('Fangoria', 'Una+temporada+en+el+infierno') hecho
# 4250:('Lola+Indigo', 'Akelarre') hecho
# 4260:('Emily+Wells', 'The+Symphonies:+Dreams+Memories+&+Parties') hecho
# 4270:('Elvis+Perkins', 'Creation+Myths') hecho
# 4280:('Cutting+Crew', 'Broadcast') hecho

# %%
lista
# Out:
# [{'id_alb': 1, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 2,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Blues Rock', 'Rock & Roll', 'Pop Rock']},
#  {'id_alb': 3, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 4, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 5, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 6,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Rumba', 'Cumbia']},
#  {'id_alb': 7, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 8, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 9, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 10,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 11,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Rock & Roll']},
#  {'id_alb': 12, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 13,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Non-Music'],
#   'subgenrse': ['Alternative Rock', 'Interview', 'Soft Rock']},
#  {'id_alb': 14, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 15,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'Psychedelic Rock']},
#  {'id_alb': 16,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Flamenco', 'Pop Rock', 'Rumba']},
#  {'id_alb': 17, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']},
#  {'id_alb': 18,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 19, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 20,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Heavy Metal']},
#  {'id_alb': 21,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Pop Rock']},
#  {'id_alb': 22,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Synth-pop', 'Disco']},
#  {'id_alb': 23, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 24,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 25,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Punk']},
#  {'id_alb': 26,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Europop', 'Pop Rock']},
#  {'id_alb': 27,
#   'gen': 'Pop',
#   'genres': ['Pop', 'Folk, World, & Country'],
#   'subgenrse': ['Ballad']},
#  {'id_alb': 28,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Rock & Roll']},
#  {'id_alb': 29, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 30,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Heavy Metal']},
#  {'id_alb': 31,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin'],
#   'subgenrse': ['Blues Rock', 'Classic Rock']},
#  {'id_alb': 32, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 33,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Brit Pop', 'Pop Rock']},
#  {'id_alb': 34, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 35, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 36, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 37,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Funk / Soul'],
#   'subgenrse': ['Disco']},
#  {'id_alb': 38,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Vocal']},
#  {'id_alb': 39,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Reggae', 'Latin'],
#   'subgenrse': ['Reggae', 'Hardcore', 'Punk', 'Dub']},
#  {'id_alb': 40,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Big Beat']},
#  {'id_alb': 41, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']},
#  {'id_alb': 42,
#   'gen': 'Hip Hop',
#   'genres': ['Hip Hop', 'Funk / Soul', 'Pop'],
#   'subgenrse': []},
#  {'id_alb': 43,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Break-In']},
#  {'id_alb': 44,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Parody']},
#  {'id_alb': 45, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 46, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 47,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Pop Rock']},
#  {'id_alb': 48, 'gen': 'Jazz', 'genres': ['Jazz'], 'subgenrse': []},
#  {'id_alb': 49,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Soft Rock', 'Pop Rock']},
#  {'id_alb': 50,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 51, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 52,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 53, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 54,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Ska']},
#  {'id_alb': 55,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Acoustic']},
#  {'id_alb': 56,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 57,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 58,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Nu Metal']},
#  {'id_alb': 59,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 60,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Arena Rock']},
#  {'id_alb': 61, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 62,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Heavy Metal']},
#  {'id_alb': 63,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 64,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Synth-pop', 'Disco']},
#  {'id_alb': 65,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin'],
#   'subgenrse': ['Ska']},
#  {'id_alb': 66,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Ska', 'Punk']},
#  {'id_alb': 67, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 68, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']},
#  {'id_alb': 69,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock'],
#   'subgenrse': ['Pop Rock', 'Synth-pop']},
#  {'id_alb': 70, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 71, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 72,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Ballad']},
#  {'id_alb': 73,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 74,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 75, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 76,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'Indie Rock']},
#  {'id_alb': 77,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Blues Rock']},
#  {'id_alb': 78,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Acoustic']},
#  {'id_alb': 79,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Synth-pop']},
#  {'id_alb': 80,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Arena Rock']},
#  {'id_alb': 81, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 82,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 83,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Ska', 'Punk']},
#  {'id_alb': 84,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Punk']},
#  {'id_alb': 85, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']},
#  {'id_alb': 86, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 87, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': ['Ska']},
#  {'id_alb': 88, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']},
#  {'id_alb': 89,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['New Wave', 'Pop Rock', 'Disco', 'Punk']},
#  {'id_alb': 90, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 91, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 92,
#   'gen': 'Pop',
#   'genres': ['Pop'],
#   'subgenrse': ['New Wave', 'Reggae-Pop', 'Synth-pop']},
#  {'id_alb': 93,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock', 'Indie Pop']},
#  {'id_alb': 94, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']},
#  {'id_alb': 95,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 96,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Disco']},
#  {'id_alb': 97,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 98, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 99,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Gothic Metal', 'Heavy Metal']},
#  {'id_alb': 100, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 101,
#   'gen': 'Pop',
#   'genres': ['Pop', 'Folk, World, & Country'],
#   'subgenrse': ['Vocal']},
#  {'id_alb': 102,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 103,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Classic Rock']},
#  {'id_alb': 104,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Funk / Soul', 'Pop'],
#   'subgenrse': ['Disco', 'Soul']},
#  {'id_alb': 105,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Hard House', 'Euro House']},
#  {'id_alb': 106,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 107, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 108,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Latin', 'Pop'],
#   'subgenrse': ['EBM']},
#  {'id_alb': 109, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 110,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Folk Rock', 'Pop Rock']},
#  {'id_alb': 111,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock'],
#   'subgenrse': ['New Wave', 'Synth-pop']},
#  {'id_alb': 112,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Acoustic', 'Pop Rock']},
#  {'id_alb': 113,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 114,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': ['Country']},
#  {'id_alb': 115, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 116,
#   'gen': 'Pop',
#   'genres': ['Pop', 'Classical', 'Folk, World, & Country'],
#   'subgenrse': ['Vocal', 'Ballad', 'Folk', 'Nordic']},
#  {'id_alb': 117,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Punk', 'Alternative Rock']},
#  {'id_alb': 118, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 119,
#   'gen': 'Latin',
#   'genres': ['Latin'],
#   'subgenrse': ['Ranchera']},
#  {'id_alb': 120,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll']},
#  {'id_alb': 121,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Speed Metal', 'Heavy Metal']},
#  {'id_alb': 122,
#   'gen': 'Pop',
#   'genres': ['Pop'],
#   'subgenrse': ['Pop Rock', 'Soft Rock', 'Ballad']},
#  {'id_alb': 123,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 124,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Death Metal']},
#  {'id_alb': 125,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Power Metal', 'Heavy Metal']},
#  {'id_alb': 126,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Heavy Metal']},
#  {'id_alb': 127,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 128, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 129,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Hard Rock', 'Pop Rock']},
#  {'id_alb': 130,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Arena Rock']},
#  {'id_alb': 131,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Power Metal', 'Heavy Metal']},
#  {'id_alb': 132,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Heavy Metal']},
#  {'id_alb': 133,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Heavy Metal']},
#  {'id_alb': 134,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Speed Metal', 'Heavy Metal']},
#  {'id_alb': 135,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 136,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Goth Rock', 'Black Metal', 'Doom Metal']},
#  {'id_alb': 137,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 138,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Art Rock', 'Heavy Metal', 'Prog Rock']},
#  {'id_alb': 139,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Heavy Metal']},
#  {'id_alb': 140,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Speed Metal', 'Heavy Metal', 'Power Metal']},
#  {'id_alb': 141,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock', 'Indie Rock']},
#  {'id_alb': 142, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 143, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 144,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Pop'],
#   'subgenrse': ['Synth-pop']},
#  {'id_alb': 145,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 146,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Heavy Metal', 'Folk Rock']},
#  {'id_alb': 147,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 148,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 149,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Non-Music'],
#   'subgenrse': ['Blues Rock', 'Interview']},
#  {'id_alb': 150,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Folk, World, & Country'],
#   'subgenrse': ['Celtic', 'Ska']},
#  {'id_alb': 151,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll']},
#  {'id_alb': 152,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Heavy Metal']},
#  {'id_alb': 153,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Prog Rock', 'Heavy Metal']},
#  {'id_alb': 154,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Punk', 'Melodic Hardcore']},
#  {'id_alb': 155,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 156,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Vocal']},
#  {'id_alb': 157, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': ['Ska']},
#  {'id_alb': 158,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Acoustic']},
#  {'id_alb': 159,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 160, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []},
#  {'id_alb': 161,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 162,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Alternative Rock']},
#  {'id_alb': 163,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Latin', 'Synth-pop', 'Ballad']},
#  {'id_alb': 164,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Blues Rock']},
#  {'id_alb': 165,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 166, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 167,
#   'gen': 'Pop',
#   'genres': ['Pop', 'Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 168,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Indie Rock']},
#  {'id_alb': 169,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Brit Pop', 'Indie Rock']},
#  {'id_alb': 170, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 171,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Nu Metal']},
#  {'id_alb': 172, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 173,
#   'gen': 'Reggae',
#   'genres': ['Reggae'],
#   'subgenrse': ['Roots Reggae']},
#  {'id_alb': 174,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 175,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 176,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Flamenco', 'Pop Rock']},
#  {'id_alb': 177,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 178,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 179,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 180,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'Classic Rock']},
#  {'id_alb': 181,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Acoustic', 'Pop Rock']},
#  {'id_alb': 182, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Glam']},
#  {'id_alb': 183,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Pop Rock']},
#  {'id_alb': 184,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Arena Rock']},
#  {'id_alb': 185,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Hard Rock', 'Heavy Metal']},
#  {'id_alb': 186,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Beat', 'Rock & Roll']},
#  {'id_alb': 187,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Psychedelic Rock', 'Pop Rock']},
#  {'id_alb': 188,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Funk / Soul', 'Pop'],
#   'subgenrse': []},
#  {'id_alb': 189, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 190,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Brit Pop', 'Indie Rock']},
#  {'id_alb': 191,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 192,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Beat']},
#  {'id_alb': 193,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Hip Hop', 'Jazz', 'Funk / Soul'],
#   'subgenrse': ['Acid House', 'Gangsta', 'Electro', 'Pop Rap']},
#  {'id_alb': 194, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 195,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Grunge']},
#  {'id_alb': 196,
#   'gen': 'Hip Hop',
#   'genres': ['Hip Hop', 'Rock'],
#   'subgenrse': ['Alternative Rock',
#    'Funk Metal',
#    'Hardcore Hip-Hop',
#    'Conscious']},
#  {'id_alb': 197, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 198,
#   'gen': 'Funk / Soul',
#   'genres': ['Funk / Soul'],
#   'subgenrse': ['Rhythm & Blues', 'Soul']},
#  {'id_alb': 199,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Dance-pop']},
#  {'id_alb': 200,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 201, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 202, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 203, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 204,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 205, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 206,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Hip Hop', 'Latin', 'Pop'],
#   'subgenrse': ['RnB/Swing', 'House', 'Flamenco', 'Hip Hop']},
#  {'id_alb': 207,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Pop'],
#   'subgenrse': ['Euro-Disco']},
#  {'id_alb': 208,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Acoustic', 'Pop Rock', 'Country Rock']},
#  {'id_alb': 209,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 210,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Reggae', 'Funk / Soul'],
#   'subgenrse': ['Reggae',
#    'Contemporary',
#    'Rocksteady',
#    'Roots Reggae',
#    'Ska',
#    'Acoustic',
#    'Soul']},
#  {'id_alb': 211,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Classic Rock']},
#  {'id_alb': 212,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 213,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'Punk']},
#  {'id_alb': 214,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['AOR', 'Classic Rock']},
#  {'id_alb': 215,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Hip Hop', 'Pop'],
#   'subgenrse': ['Indie Pop']},
#  {'id_alb': 216,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Pop Rock']},
#  {'id_alb': 217,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 218,
#   'gen': 'Hip Hop',
#   'genres': ['Hip Hop', 'Funk / Soul', 'Pop'],
#   'subgenrse': ['Contemporary R&B']},
#  {'id_alb': 219,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock']},
#  {'id_alb': 220,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock', 'Indie Rock']},
#  {'id_alb': 221,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Ballad']},
#  {'id_alb': 222,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal', 'Power Metal']},
#  {'id_alb': 223,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Folk Rock']},
#  {'id_alb': 224, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 225,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Funk / Soul', 'Folk, World, & Country'],
#   'subgenrse': ['Flamenco', 'Funk']},
#  {'id_alb': 226, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 227,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Reggae', 'Pop'],
#   'subgenrse': ['Euro House', 'Europop', 'Reggae-Pop']},
#  {'id_alb': 228,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 229,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Downtempo', 'Disco']},
#  {'id_alb': 230,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 231, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 232,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['New Wave', 'Punk']},
#  {'id_alb': 233,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Prog Rock', 'Classic Rock', 'Pop Rock']},
#  {'id_alb': 234, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 235,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Psychedelic Rock']},
#  {'id_alb': 236, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 237, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 238,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 239, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 240,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Vocal', 'Ballad', 'Pop Rock']},
#  {'id_alb': 241,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Europop']},
#  {'id_alb': 242, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []},
#  {'id_alb': 243,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['House', 'Euro House', 'Disco']},
#  {'id_alb': 244,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Ballad', 'Vocal']},
#  {'id_alb': 245, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []},
#  {'id_alb': 246, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 247, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 248,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 249,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Folk, World, & Country'],
#   'subgenrse': ['Alternative Rock', 'Folk Rock']},
#  {'id_alb': 250,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 251,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Synth-pop', 'Alternative Rock', 'Punk']},
#  {'id_alb': 252, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 253,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Punk', 'Melodic Hardcore']},
#  {'id_alb': 254, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 255,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Soft Rock', 'Pop Rock']},
#  {'id_alb': 256, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 257,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock', 'Chanson']},
#  {'id_alb': 258,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock', 'Indie Rock']},
#  {'id_alb': 259, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 260,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 261,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Classical', 'Folk, World, & Country'],
#   'subgenrse': ['Art Rock']},
#  {'id_alb': 262,
#   'gen': 'Funk / Soul',
#   'genres': ['Funk / Soul', 'Pop'],
#   'subgenrse': ['Vocal']},
#  {'id_alb': 263,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 264, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 265,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Acoustic', 'Pop Rock']},
#  {'id_alb': 266,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Brit Pop', 'Indie Rock']},
#  {'id_alb': 267,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Prog Rock', 'Heavy Metal']},
#  {'id_alb': 268,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Brit Pop']},
#  {'id_alb': 269,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 270,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Rock & Roll', 'Blues Rock']},
#  {'id_alb': 271,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Soft Rock']},
#  {'id_alb': 272,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Grunge']},
#  {'id_alb': 273,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin'],
#   'subgenrse': ['Flamenco']},
#  {'id_alb': 274, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 275, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 276, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 277, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 278,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Soft Rock', 'Ballad', 'Synth-pop']},
#  {'id_alb': 279,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['New Wave', 'Pop Rock', 'Post-Punk']},
#  {'id_alb': 280,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Beat']},
#  {'id_alb': 281,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['New Wave', 'Punk']},
#  {'id_alb': 282, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 283,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Ska']},
#  {'id_alb': 284,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll']},
#  {'id_alb': 285,
#   'gen': 'Hip Hop',
#   'genres': ['Hip Hop', 'Pop'],
#   'subgenrse': ['Pop Rap', 'Conscious']},
#  {'id_alb': 286, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 287,
#   'gen': 'Electronic',
#   'genres': ['Electronic',
#    'Hip Hop',
#    'Rock',
#    'Reggae',
#    'Funk / Soul',
#    'Blues'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 288,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Gothic Metal']},
#  {'id_alb': 289,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 290,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 291,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 292,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Punk']},
#  {'id_alb': 293,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Prog Rock', 'Art Rock']},
#  {'id_alb': 294, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Ska']},
#  {'id_alb': 295,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Folk Rock', 'Alternative Rock']},
#  {'id_alb': 296, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 297,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Synth-pop']},
#  {'id_alb': 298,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Heavy Metal']},
#  {'id_alb': 299,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Funk / Soul'],
#   'subgenrse': ['Contemporary R&B', 'Electro']},
#  {'id_alb': 300, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 301,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Hard Rock', 'Arena Rock', 'Ballad', 'Pop Rock']},
#  {'id_alb': 302,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Funk / Soul'],
#   'subgenrse': ['New Wave', 'Pop Rock', 'Soul', 'Rhythm & Blues']},
#  {'id_alb': 303,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 304,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Hi NRG', 'Disco']},
#  {'id_alb': 305,
#   'gen': 'Jazz',
#   'genres': ['Jazz', 'Rock', 'Folk, World, & Country'],
#   'subgenrse': ['Folk Rock', 'Psychedelic Rock']},
#  {'id_alb': 306,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Speed Metal', 'Heavy Metal']},
#  {'id_alb': 307, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['AOR']},
#  {'id_alb': 308,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Folk Rock',
#    'Pachanga',
#    'Southern Rock',
#    'Rumba',
#    'Acoustic',
#    'Flamenco']},
#  {'id_alb': 309,
#   'gen': 'Blues',
#   'genres': ['Blues', 'Pop'],
#   'subgenrse': ['Doo Wop', 'Rhythm & Blues', 'Vocal']},
#  {'id_alb': 310,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 311,
#   'gen': 'Funk / Soul',
#   'genres': ['Funk / Soul'],
#   'subgenrse': ['Soul']},
#  {'id_alb': 312,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 313,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin'],
#   'subgenrse': ['Acoustic', 'Pop Rock']},
#  {'id_alb': 314, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 315, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 316,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock'],
#   'subgenrse': ['Soft Rock', 'Synth-pop']},
#  {'id_alb': 317, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 318,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Prog Rock', 'Symphonic Rock']},
#  {'id_alb': 319,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Punk', 'Alternative Rock', 'Pop Punk']},
#  {'id_alb': 320,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Soft Rock', 'Pop Rock']},
#  {'id_alb': 321, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 322, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 323,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 324, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 325, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 326, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 327, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 328,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 329, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': ['Rumba']},
#  {'id_alb': 330, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']},
#  {'id_alb': 331,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 332,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 333, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 334,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Indie Rock', 'Shoegaze', 'Noise']},
#  {'id_alb': 335,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock', 'Shoegaze']},
#  {'id_alb': 336,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 337,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 338,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Synth-pop']},
#  {'id_alb': 339,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Soft Rock', 'Pop Rock', 'Vocal']},
#  {'id_alb': 340,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 341,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 342,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['House', 'Synth-pop']},
#  {'id_alb': 343, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Acoustic']},
#  {'id_alb': 344, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 345, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 346,
#   'gen': 'Reggae',
#   'genres': ['Reggae', 'Pop'],
#   'subgenrse': []},
#  {'id_alb': 347,
#   'gen': 'Pop',
#   'genres': ['Pop'],
#   'subgenrse': ['Rock & Roll']},
#  {'id_alb': 348,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Ballad']},
#  {'id_alb': 349,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Alternative Rock']},
#  {'id_alb': 350, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 351,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Alternative Rock', 'Soft Rock']},
#  {'id_alb': 352,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Latin', 'Pop'],
#   'subgenrse': ['Europop', 'Synth-pop']},
#  {'id_alb': 353, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']},
#  {'id_alb': 354, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 355, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 356,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Indie Pop', 'Folk Rock']},
#  {'id_alb': 357, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 358, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 359,
#   'gen': 'Funk / Soul',
#   'genres': ['Funk / Soul'],
#   'subgenrse': ['Disco', 'Reggae-Pop']},
#  {'id_alb': 360, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 361,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Europop']},
#  {'id_alb': 362,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Funk / Soul', 'Pop'],
#   'subgenrse': ['Contemporary R&B', 'Ballad', 'House']},
#  {'id_alb': 363,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Europop', 'Brit Pop', 'Pop Rock']},
#  {'id_alb': 364,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Country Rock']},
#  {'id_alb': 365,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Pop'],
#   'subgenrse': ['Synth-pop', 'Pop Rock']},
#  {'id_alb': 366,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 367,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Soft Rock', 'Pop Rock']},
#  {'id_alb': 368, 'gen': 'Jazz', 'genres': ['Jazz'], 'subgenrse': ['Post Bop']},
#  {'id_alb': 369,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Hip Hop', 'Rock', 'Funk / Soul'],
#   'subgenrse': ['Pop Rap', 'Pop Rock', 'Disco', 'Contemporary R&B']},
#  {'id_alb': 370,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Speed Metal', 'Heavy Metal', 'Power Metal']},
#  {'id_alb': 371,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Prog Rock']},
#  {'id_alb': 372,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Pop'],
#   'subgenrse': ['Synth-pop']},
#  {'id_alb': 373,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 374, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 375,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Folk, World, & Country'],
#   'subgenrse': ['Folk Rock', 'Celtic', 'Punk']},
#  {'id_alb': 376, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 377,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal', 'Power Metal']},
#  {'id_alb': 378,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Ballad', 'Bolero', 'Vocal']},
#  {'id_alb': 379,
#   'gen': 'Hip Hop',
#   'genres': ['Hip Hop', 'Rock', 'Pop'],
#   'subgenrse': ['RnB/Swing']},
#  {'id_alb': 380, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 381,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'Prog Rock']},
#  {'id_alb': 382,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 383,
#   'gen': 'Hip Hop',
#   'genres': ['Hip Hop', 'Rock', 'Latin'],
#   'subgenrse': ['Alternative Rock', 'Ska']},
#  {'id_alb': 384, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 385, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 386,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Interview', 'Pop Rock']},
#  {'id_alb': 387,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Alternative Rock']},
#  {'id_alb': 388,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin'],
#   'subgenrse': ['Pop Rock', 'Rumba']},
#  {'id_alb': 389,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 390,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Soft Rock']},
#  {'id_alb': 391,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Folk, World, & Country'],
#   'subgenrse': ['Country', 'Rockabilly']},
#  {'id_alb': 392, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': []},
#  {'id_alb': 393,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Acoustic', 'Pop Rock', 'Rockabilly']},
#  {'id_alb': 394,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Blues Rock']},
#  {'id_alb': 395,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Synth-pop']},
#  {'id_alb': 396,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll']},
#  {'id_alb': 397,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 398,
#   'gen': 'Hip Hop',
#   'genres': ['Hip Hop'],
#   'subgenrse': ['Ragga HipHop']},
#  {'id_alb': 399, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 400,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Soft Rock']},
#  {'id_alb': 401,
#   'gen': 'Hip Hop',
#   'genres': ['Hip Hop', 'Funk / Soul', 'Pop'],
#   'subgenrse': ['Pop Rap']},
#  {'id_alb': 402, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 403,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Blues', 'Folk, World, & Country'],
#   'subgenrse': ['Folk Rock']},
#  {'id_alb': 404,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Country Rock']},
#  {'id_alb': 405,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Arena Rock', 'Pop Rock']},
#  {'id_alb': 406, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 407,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Speed Metal', 'Heavy Metal']},
#  {'id_alb': 408,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Synth-pop']},
#  {'id_alb': 409,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 410,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'New Wave', 'Shoegaze', 'Pop Rock']},
#  {'id_alb': 411,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 412,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 413, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Acoustic']},
#  {'id_alb': 414,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Reggae', 'Funk / Soul', 'Non-Music', 'Pop'],
#   'subgenrse': ['Interview', 'Europop']},
#  {'id_alb': 415,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': []},
#  {'id_alb': 416, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 417,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Folk, World, & Country'],
#   'subgenrse': ['Bolero', 'Ranchera']},
#  {'id_alb': 418,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'Punk']},
#  {'id_alb': 419,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock'],
#   'subgenrse': ['Pop Rock', 'Downtempo', 'Synth-pop']},
#  {'id_alb': 420,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop', 'Folk, World, & Country'],
#   'subgenrse': ['Folk Rock', 'Pop Rock']},
#  {'id_alb': 421, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 422,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Soft Rock']},
#  {'id_alb': 423,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 424,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop', 'Folk, World, & Country'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 425, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 426,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 427,
#   'gen': 'Blues',
#   'genres': ['Blues', 'Pop'],
#   'subgenrse': ['Ballad']},
#  {'id_alb': 428,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Country Rock', 'Soft Rock']},
#  {'id_alb': 429, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 430, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []},
#  {'id_alb': 431, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 432, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 433,
#   'gen': 'Jazz',
#   'genres': ['Jazz', 'Rock'],
#   'subgenrse': ['Lounge', 'Parody']},
#  {'id_alb': 434,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 435, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 436,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Punk']},
#  {'id_alb': 437, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 438,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Bubblegum']},
#  {'id_alb': 439,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Big Beat']},
#  {'id_alb': 440, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 441,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 442,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Acoustic', 'Pop Rock']},
#  {'id_alb': 443, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 444,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll']},
#  {'id_alb': 445, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 446,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 447,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop', 'Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 448,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Ska', 'Punk']},
#  {'id_alb': 449,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Folk, World, & Country'],
#   'subgenrse': ['Nueva Cancion', 'Folk']},
#  {'id_alb': 450, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Ska']},
#  {'id_alb': 451, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 452,
#   'gen': 'Jazz',
#   'genres': ['Jazz', 'Reggae'],
#   'subgenrse': ['Ska', 'Swing']},
#  {'id_alb': 453, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': []},
#  {'id_alb': 454,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Garage Rock', 'Pop Rock']},
#  {'id_alb': 455, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 456,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Pop Rock']},
#  {'id_alb': 457,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Acoustic', 'Pop Rock']},
#  {'id_alb': 458,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock', 'Vocal']},
#  {'id_alb': 459,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Hard Rock']},
#  {'id_alb': 460,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock'],
#   'subgenrse': ['Symphonic Rock', 'Prog Rock', 'AOR', 'Synth-pop']},
#  {'id_alb': 461,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 462,
#   'gen': 'Pop',
#   'genres': ['Pop', 'Folk, World, & Country', 'Stage & Screen'],
#   'subgenrse': ['Vocal']},
#  {'id_alb': 463,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Southern Rock', 'Hard Rock', 'Glam']},
#  {'id_alb': 464, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Glam']},
#  {'id_alb': 465,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Arena Rock', 'Hard Rock']},
#  {'id_alb': 466,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock',
#    'Pop Rock',
#    'Classic Rock',
#    'Arena Rock',
#    'Rock Opera']},
#  {'id_alb': 467,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 468,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 469,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Southern Rock']},
#  {'id_alb': 470,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 471, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 472,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Heavy Metal']},
#  {'id_alb': 473,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Glam']},
#  {'id_alb': 474, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 475,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal', 'Glam']},
#  {'id_alb': 476,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Heavy Metal']},
#  {'id_alb': 477, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 478, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 479,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 480,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 481,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 482,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Heavy Metal']},
#  {'id_alb': 483, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 484, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 485, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 486,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Glam']},
#  {'id_alb': 487, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 488, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 489,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Arena Rock', 'Pop Rock', 'AOR']},
#  {'id_alb': 490,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock', 'Hard Rock']},
#  {'id_alb': 491, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 492,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Glam', 'Hard Rock']},
#  {'id_alb': 493,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Glam', 'Hard Rock']},
#  {'id_alb': 494, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 495,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 496, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 497,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Synth-pop']},
#  {'id_alb': 498,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'Classic Rock']},
#  {'id_alb': 499, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Nu Metal']},
#  {'id_alb': 500, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 501, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 502, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 503,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Country Rock']},
#  {'id_alb': 504, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 505,
#   'gen': 'Rock',
#   'genres': ['Rock'],
# ...
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Indie Rock']},
#  {'id_alb': 842,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Folk, World, & Country'],
#   'subgenrse': ['Folk Rock', 'Indie Rock', 'Folk']},
#  {'id_alb': 843,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Blues', 'Folk, World, & Country'],
#   'subgenrse': ['Blues Rock', 'Country Rock', 'Country Blues', 'Texas Blues']},
#  {'id_alb': 844,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Folk, World, & Country'],
#   'subgenrse': ['Country Rock', 'Country']},
#  {'id_alb': 845,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Rock & Roll']},
#  {'id_alb': 846,
#   'gen': 'Electronic',
#   'genres': ['Electronic'],
#   'subgenrse': ['Synth-pop']},
#  {'id_alb': 847, 'gen': 'Rock', 'genres': ['Rock', 'Blues'], 'subgenrse': []},
#  {'id_alb': 848,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Pop Rock', 'Classic Rock']},
#  {'id_alb': 849,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 850,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Funk / Soul'],
#   'subgenrse': ['Soul', 'Funk']},
#  {'id_alb': 851,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['New Wave', 'Rock & Roll']},
#  {'id_alb': 852,
#   'gen': 'Funk / Soul',
#   'genres': ['Funk / Soul'],
#   'subgenrse': ['Soul']},
#  {'id_alb': 853, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []},
#  {'id_alb': 854, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 855, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 856,
#   'gen': 'Funk / Soul',
#   'genres': ['Funk / Soul'],
#   'subgenrse': ['Soul', 'Disco']},
#  {'id_alb': 857, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 858, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 859,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 860,
#   'gen': 'Pop',
#   'genres': ['Pop', 'Folk, World, & Country'],
#   'subgenrse': ['Ballad', 'Vocal', 'Folk']},
#  {'id_alb': 861, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['New Wave']},
#  {'id_alb': 862,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Garage Rock']},
#  {'id_alb': 863, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 864, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 865, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 866,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Power Pop']},
#  {'id_alb': 867, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 868, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 869,
#   'gen': 'Pop',
#   'genres': ['Pop', 'Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 870,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Punk', 'Pop Rock']},
#  {'id_alb': 871, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 872, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 873,
#   'gen': 'Funk / Soul',
#   'genres': ['Funk / Soul'],
#   'subgenrse': ['Rhythm & Blues']},
#  {'id_alb': 874,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'New Wave']},
#  {'id_alb': 875,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Pop'],
#   'subgenrse': ['Synth-pop']},
#  {'id_alb': 876,
#   'gen': 'Jazz',
#   'genres': ['Jazz', 'Pop', 'Stage & Screen'],
#   'subgenrse': ['Lounge', 'Theme']},
#  {'id_alb': 877,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Indie Rock']},
#  {'id_alb': 878,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock', 'Punk', 'Ska']},
#  {'id_alb': 879, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 880, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 881, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 882,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Funk / Soul', 'Pop'],
#   'subgenrse': ['Rhythm & Blues', 'Doo Wop']},
#  {'id_alb': 883,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 884, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']},
#  {'id_alb': 885,
#   'gen': 'Jazz',
#   'genres': ['Jazz', 'Rock'],
#   'subgenrse': ['Lounge', 'Alternative Rock', 'Parody']},
#  {'id_alb': 886, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Indie Pop']},
#  {'id_alb': 887,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 888,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 889,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Blues Rock', 'Indie Rock']},
#  {'id_alb': 890, 'gen': 'Hip Hop', 'genres': ['Hip Hop'], 'subgenrse': []},
#  {'id_alb': 891,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin'],
#   'subgenrse': ['Afro-Cuban',
#    'Fusion',
#    'Samba',
#    'Blues Rock',
#    'Psychedelic Rock']},
#  {'id_alb': 892,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Soft Rock', 'Pop Rock']},
#  {'id_alb': 893,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Acoustic', 'Pop Rock', 'Classic Rock']},
#  {'id_alb': 894,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'Hard Rock', 'Rock & Roll']},
#  {'id_alb': 895,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock', 'Acoustic']},
#  {'id_alb': 896,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Indie Rock',
#    'Alternative Rock',
#    'Blues Rock',
#    'Garage Rock']},
#  {'id_alb': 897,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': ['Country']},
#  {'id_alb': 898,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 899, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 900,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Art Rock', 'Pop Rock', 'Classic Rock', 'Prog Rock']},
#  {'id_alb': 901,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Hip Hop', 'Jazz', 'Rock', 'Pop'],
#   'subgenrse': ['Instrumental', 'House', 'Jazz-Rock', 'Electro', 'Trip Hop']},
#  {'id_alb': 902,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Country Rock', 'Pop Rock']},
#  {'id_alb': 903,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop', 'Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 904, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 905,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 906,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Indie Rock']},
#  {'id_alb': 907,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Indie Rock']},
#  {'id_alb': 908, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []},
#  {'id_alb': 909, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 910,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Folk Rock']},
#  {'id_alb': 911,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock'],
#   'subgenrse': ['Leftfield', 'Indie Rock']},
#  {'id_alb': 912,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Soft Rock']},
#  {'id_alb': 913,
#   'gen': 'Funk / Soul',
#   'genres': ['Funk / Soul', 'Pop'],
#   'subgenrse': ['Soul', 'Ballad', 'Pop Rock']},
#  {'id_alb': 914,
#   'gen': 'Jazz',
#   'genres': ['Jazz', 'Latin'],
#   'subgenrse': ['Bossa Nova', 'Easy Listening']},
#  {'id_alb': 915,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Indie Rock']},
#  {'id_alb': 916,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 917,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 918, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Surf']},
#  {'id_alb': 919,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 920,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Soft Rock']},
#  {'id_alb': 921,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock', 'Pop Rock']},
#  {'id_alb': 922,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll']},
#  {'id_alb': 923,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Rock & Roll', 'Garage Rock', 'Pop Rock']},
#  {'id_alb': 924,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Pop Rock', 'Classic Rock']},
#  {'id_alb': 925,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Psychedelic Rock', 'Pop Rock', 'Classic Rock']},
#  {'id_alb': 926, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 927,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Stage & Screen'],
#   'subgenrse': ['Pop Rock', 'Soundtrack']},
#  {'id_alb': 928,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 929,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Mod']},
#  {'id_alb': 930,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock']},
#  {'id_alb': 931, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 932,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Pop Rock']},
#  {'id_alb': 933, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 934,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 935,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock', 'Glam']},
#  {'id_alb': 936,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock', 'Pop Rock', 'Indie Rock']},
#  {'id_alb': 937, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 938,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Pop Rock']},
#  {'id_alb': 939,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll']},
#  {'id_alb': 940, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 941, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 942,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Reggae'],
#   'subgenrse': ['Rock & Roll', 'Dub', 'Punk']},
#  {'id_alb': 943, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 944, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 945,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 946,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Soft Rock', 'Southern Rock']},
#  {'id_alb': 947,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Ballad']},
#  {'id_alb': 948,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Rock & Roll']},
#  {'id_alb': 949,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': []},
#  {'id_alb': 950,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Hard Rock']},
#  {'id_alb': 951,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Acoustic', 'Hard Rock', 'Garage Rock']},
#  {'id_alb': 952, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 953,
#   'gen': 'Jazz',
#   'genres': ['Jazz'],
#   'subgenrse': ['Soul-Jazz', 'Vocal']},
#  {'id_alb': 954,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Rumba']},
#  {'id_alb': 955,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Classic Rock']},
#  {'id_alb': 956,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Folk, World, & Country'],
#   'subgenrse': ['Folk Rock', 'Folk', 'Blues Rock']},
#  {'id_alb': 957,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Latin', 'Pop'],
#   'subgenrse': ['Flamenco', 'Ska', 'Rumba']},
#  {'id_alb': 958,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 959,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Rock & Roll', 'Pop Rock']},
#  {'id_alb': 960, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 961,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': ['Country']},
#  {'id_alb': 962,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Vocal']},
#  {'id_alb': 963,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Reggae'],
#   'subgenrse': ['Punk', 'Ska', 'Reggae']},
#  {'id_alb': 964,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Reggae'],
#   'subgenrse': ['Reggae', 'Pop Rock']},
#  {'id_alb': 965,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Hip Hop'],
#   'subgenrse': ['Breakbeat', 'Ragga HipHop', 'Grime', 'Electro', 'Breaks']},
#  {'id_alb': 966,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock', 'Pop', 'Folk, World, & Country'],
#   'subgenrse': ['Folk Rock', 'Electro', 'Pop Rock']},
#  {'id_alb': 967,
#   'gen': 'Reggae',
#   'genres': ['Reggae'],
#   'subgenrse': ['Reggae-Pop']},
#  {'id_alb': 968, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 969, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []},
#  {'id_alb': 970,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Reggae', 'Latin', 'Pop', 'Folk, World, & Country'],
#   'subgenrse': ['Reggae',
#    'Modern Classical',
#    'Raï',
#    'Europop',
#    'Hip Hop',
#    'Downtempo']},
#  {'id_alb': 971,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Pop'],
#   'subgenrse': ['Parody']},
#  {'id_alb': 972,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Acoustic', 'Pop Rock']},
#  {'id_alb': 973,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock', 'Pop'],
#   'subgenrse': ['Pop Rock', 'Synth-pop', 'Experimental', 'Trip Hop']},
#  {'id_alb': 974,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Alternative Rock']},
#  {'id_alb': 975,
#   'gen': 'Pop',
#   'genres': ['Pop', 'Folk, World, & Country'],
#   'subgenrse': ['Country', 'Bluegrass', 'Country Rock']},
#  {'id_alb': 976,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Indie Rock', 'Disco']},
#  {'id_alb': 977,
#   'gen': 'Hip Hop',
#   'genres': ['Hip Hop', 'Funk / Soul', 'Pop'],
#   'subgenrse': ['Contemporary R&B']},
#  {'id_alb': 978,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Salsa', 'Vocal', 'Ballad']},
#  {'id_alb': 979, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']},
#  {'id_alb': 980,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Heavy Metal']},
#  {'id_alb': 981,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Pop'],
#   'subgenrse': ['Synth-pop', 'Vocal']},
#  {'id_alb': 982,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': ['Country']},
#  {'id_alb': 983,
#   'gen': 'Blues',
#   'genres': ['Blues', 'Folk, World, & Country'],
#   'subgenrse': ['Country Blues', 'Folk']},
#  {'id_alb': 984,
#   'gen': 'Latin',
#   'genres': ['Latin', 'Pop'],
#   'subgenrse': ['Vocal']},
#  {'id_alb': 985,
#   'gen': 'Electronic',
#   'genres': ['Electronic', 'Rock'],
#   'subgenrse': ['Soft Rock', 'Downtempo']},
#  {'id_alb': 986,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 987,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': ['Country', 'Bluegrass']},
#  {'id_alb': 988,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': ['Country']},
#  {'id_alb': 989,
#   'gen': 'Pop',
#   'genres': ['Pop', 'Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 990, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 991,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': ['Country']},
#  {'id_alb': 992, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 993, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 994,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Funk / Soul', 'Pop'],
#   'subgenrse': ['Art Rock', 'Pop Rock']},
#  {'id_alb': 995,
#   'gen': 'Rock',
#   'genres': ['Rock'],
#   'subgenrse': ['Symphonic Metal']},
#  {'id_alb': 996, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']},
#  {'id_alb': 997, 'gen': nan, 'genres': nan, 'subgenrse': nan},
#  {'id_alb': 998,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': ['Country']},
#  {'id_alb': 999,
#   'gen': 'Rock',
#   'genres': ['Rock', 'Folk, World, & Country'],
#   'subgenrse': []},
#  {'id_alb': 1000,
#   'gen': 'Folk, World, & Country',
#   'genres': ['Folk, World, & Country'],
#   'subgenrse': ['Country']},
#  ...]

# %%
generosdf = pd.DataFrame(lista)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-182616add458> in <module>
# ----> 1 generosdf = pd.DataFrame(lista)
#
# ~/anaconda3/envs/sinatxe/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     720                         # ndarray], Index, Series], Sequence[Any]]"
#     721                         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 722                     arrays, columns, index = nested_data_to_arrays(
#     723                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     724                         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#
# ~/anaconda3/envs/sinatxe/lib/python3.8/site-packages/pandas/core/internals/construction.py in nested_data_to_arrays(data, columns, index, dtype)
#     517         columns = ensure_index(data[0]._fields)
#     518
# --> 519     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     520     columns = ensure_index(columns)
#     521
#
# ~/anaconda3/envs/sinatxe/lib/python3.8/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, dtype)
#     873         arr = _list_to_arrays(data)
#     874     elif isinstance(data[0], abc.Mapping):
# --> 875         arr, columns = _list_of_dict_to_arrays(data, columns)
#     876     elif isinstance(data[0], ABCSeries):
#     877         arr, columns = _list_of_series_to_arrays(data, columns)
#
# ~/anaconda3/envs/sinatxe/lib/python3.8/site-packages/pandas/core/internals/construction.py in _list_of_dict_to_arrays(data, columns)
#     958         gen = (list(x.keys()) for x in data)
#     959         sort = not any(isinstance(d, dict) for d in data)
# --> 960         pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     961         columns = ensure_index(pre_cols)
#     962
#
# ~/anaconda3/envs/sinatxe/lib/python3.8/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# ~/anaconda3/envs/sinatxe/lib/python3.8/site-packages/pandas/core/internals/construction.py in <genexpr>(.0)
#     956     """
#     957     if columns is None:
# --> 958         gen = (list(x.keys()) for x in data)
#     959         sort = not any(isinstance(d, dict) for d in data)
#     960         pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
albums_genero = albums.merge(generosdf)

# %%
for l in lista:
    print(l)
# Out:
# {'id_alb': 1, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 2, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Blues Rock', 'Rock & Roll', 'Pop Rock']}
# {'id_alb': 3, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 5, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 6, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Pop Rock', 'Rumba', 'Cumbia']}
# {'id_alb': 7, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 8, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 9, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 10, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 11, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Rock & Roll']}
# {'id_alb': 12, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 13, 'gen': 'Rock', 'genres': ['Rock', 'Non-Music'], 'subgenrse': ['Alternative Rock', 'Interview', 'Soft Rock']}
# {'id_alb': 14, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 15, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock', 'Psychedelic Rock']}
# {'id_alb': 16, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Flamenco', 'Pop Rock', 'Rumba']}
# {'id_alb': 17, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']}
# {'id_alb': 18, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock']}
# {'id_alb': 19, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 20, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Heavy Metal']}
# {'id_alb': 21, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll', 'Pop Rock']}
# {'id_alb': 22, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop', 'Disco']}
# {'id_alb': 23, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 24, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 25, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Punk']}
# {'id_alb': 26, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Europop', 'Pop Rock']}
# {'id_alb': 27, 'gen': 'Pop', 'genres': ['Pop', 'Folk, World, & Country'], 'subgenrse': ['Ballad']}
# {'id_alb': 28, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Rock & Roll']}
# {'id_alb': 29, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 30, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Heavy Metal']}
# {'id_alb': 31, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': ['Blues Rock', 'Classic Rock']}
# {'id_alb': 32, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 33, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Brit Pop', 'Pop Rock']}
# {'id_alb': 34, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 35, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 36, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 37, 'gen': 'Electronic', 'genres': ['Electronic', 'Funk / Soul'], 'subgenrse': ['Disco']}
# {'id_alb': 38, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Vocal']}
# {'id_alb': 39, 'gen': 'Rock', 'genres': ['Rock', 'Reggae', 'Latin'], 'subgenrse': ['Reggae', 'Hardcore', 'Punk', 'Dub']}
# {'id_alb': 40, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Big Beat']}
# {'id_alb': 41, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 42, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Funk / Soul', 'Pop'], 'subgenrse': []}
# {'id_alb': 43, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Break-In']}
# {'id_alb': 44, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Parody']}
# {'id_alb': 45, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 46, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 47, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Pop Rock']}
# {'id_alb': 48, 'gen': 'Jazz', 'genres': ['Jazz'], 'subgenrse': []}
# {'id_alb': 49, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Soft Rock', 'Pop Rock']}
# {'id_alb': 50, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 51, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 52, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 53, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 54, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Ska']}
# {'id_alb': 55, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Acoustic']}
# {'id_alb': 56, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 57, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 58, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Nu Metal']}
# {'id_alb': 59, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 60, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Arena Rock']}
# {'id_alb': 61, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 62, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Heavy Metal']}
# {'id_alb': 63, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock']}
# {'id_alb': 64, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop', 'Disco']}
# {'id_alb': 65, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': ['Ska']}
# {'id_alb': 66, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Ska', 'Punk']}
# {'id_alb': 67, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 68, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 69, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['Pop Rock', 'Synth-pop']}
# {'id_alb': 70, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 71, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 72, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': ['Ballad']}
# {'id_alb': 73, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 74, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 75, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 76, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock', 'Indie Rock']}
# {'id_alb': 77, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Blues Rock']}
# {'id_alb': 78, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Acoustic']}
# {'id_alb': 79, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 80, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Arena Rock']}
# {'id_alb': 81, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 82, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 83, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Ska', 'Punk']}
# {'id_alb': 84, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll', 'Punk']}
# {'id_alb': 85, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 86, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 87, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': ['Ska']}
# {'id_alb': 88, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']}
# {'id_alb': 89, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['New Wave', 'Pop Rock', 'Disco', 'Punk']}
# {'id_alb': 90, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 91, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 92, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['New Wave', 'Reggae-Pop', 'Synth-pop']}
# {'id_alb': 93, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Alternative Rock', 'Indie Pop']}
# {'id_alb': 94, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 95, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 96, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Disco']}
# {'id_alb': 97, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 98, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 99, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Gothic Metal', 'Heavy Metal']}
# {'id_alb': 100, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 101, 'gen': 'Pop', 'genres': ['Pop', 'Folk, World, & Country'], 'subgenrse': ['Vocal']}
# {'id_alb': 102, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 103, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Classic Rock']}
# {'id_alb': 104, 'gen': 'Electronic', 'genres': ['Electronic', 'Funk / Soul', 'Pop'], 'subgenrse': ['Disco', 'Soul']}
# {'id_alb': 105, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Hard House', 'Euro House']}
# {'id_alb': 106, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 107, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 108, 'gen': 'Electronic', 'genres': ['Electronic', 'Latin', 'Pop'], 'subgenrse': ['EBM']}
# {'id_alb': 109, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 110, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Folk Rock', 'Pop Rock']}
# {'id_alb': 111, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['New Wave', 'Synth-pop']}
# {'id_alb': 112, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Acoustic', 'Pop Rock']}
# {'id_alb': 113, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Alternative Rock', 'Pop Rock']}
# {'id_alb': 114, 'gen': 'Folk, World, & Country', 'genres': ['Folk, World, & Country'], 'subgenrse': ['Country']}
# {'id_alb': 115, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 116, 'gen': 'Pop', 'genres': ['Pop', 'Classical', 'Folk, World, & Country'], 'subgenrse': ['Vocal', 'Ballad', 'Folk', 'Nordic']}
# {'id_alb': 117, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk', 'Alternative Rock']}
# {'id_alb': 118, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 119, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': ['Ranchera']}
# {'id_alb': 120, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll']}
# {'id_alb': 121, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Speed Metal', 'Heavy Metal']}
# {'id_alb': 122, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Pop Rock', 'Soft Rock', 'Ballad']}
# {'id_alb': 123, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 124, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Death Metal']}
# {'id_alb': 125, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Power Metal', 'Heavy Metal']}
# {'id_alb': 126, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Heavy Metal']}
# {'id_alb': 127, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 128, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 129, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Hard Rock', 'Pop Rock']}
# {'id_alb': 130, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Arena Rock']}
# {'id_alb': 131, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Power Metal', 'Heavy Metal']}
# {'id_alb': 132, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Heavy Metal']}
# {'id_alb': 133, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Heavy Metal']}
# {'id_alb': 134, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Speed Metal', 'Heavy Metal']}
# {'id_alb': 135, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 136, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Goth Rock', 'Black Metal', 'Doom Metal']}
# {'id_alb': 137, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 138, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Art Rock', 'Heavy Metal', 'Prog Rock']}
# {'id_alb': 139, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Heavy Metal']}
# {'id_alb': 140, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Speed Metal', 'Heavy Metal', 'Power Metal']}
# {'id_alb': 141, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock', 'Indie Rock']}
# {'id_alb': 142, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 143, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 144, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 145, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 146, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Heavy Metal', 'Folk Rock']}
# {'id_alb': 147, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 148, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 149, 'gen': 'Rock', 'genres': ['Rock', 'Non-Music'], 'subgenrse': ['Blues Rock', 'Interview']}
# {'id_alb': 150, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': ['Celtic', 'Ska']}
# {'id_alb': 151, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll']}
# {'id_alb': 152, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Heavy Metal']}
# {'id_alb': 153, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Prog Rock', 'Heavy Metal']}
# {'id_alb': 154, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk', 'Melodic Hardcore']}
# {'id_alb': 155, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 156, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': ['Vocal']}
# {'id_alb': 157, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': ['Ska']}
# {'id_alb': 158, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Acoustic']}
# {'id_alb': 159, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 160, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 161, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 162, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Alternative Rock']}
# {'id_alb': 163, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': ['Latin', 'Synth-pop', 'Ballad']}
# {'id_alb': 164, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll', 'Blues Rock']}
# {'id_alb': 165, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 166, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 167, 'gen': 'Pop', 'genres': ['Pop', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 168, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Indie Rock']}
# {'id_alb': 169, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Brit Pop', 'Indie Rock']}
# {'id_alb': 170, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 171, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Nu Metal']}
# {'id_alb': 172, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 173, 'gen': 'Reggae', 'genres': ['Reggae'], 'subgenrse': ['Roots Reggae']}
# {'id_alb': 174, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 175, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 176, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Flamenco', 'Pop Rock']}
# {'id_alb': 177, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 178, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 179, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 180, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock', 'Classic Rock']}
# {'id_alb': 181, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Acoustic', 'Pop Rock']}
# {'id_alb': 182, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Glam']}
# {'id_alb': 183, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll', 'Pop Rock']}
# {'id_alb': 184, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Arena Rock']}
# {'id_alb': 185, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll', 'Hard Rock', 'Heavy Metal']}
# {'id_alb': 186, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Beat', 'Rock & Roll']}
# {'id_alb': 187, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Psychedelic Rock', 'Pop Rock']}
# {'id_alb': 188, 'gen': 'Rock', 'genres': ['Rock', 'Funk / Soul', 'Pop'], 'subgenrse': []}
# {'id_alb': 189, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 190, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Brit Pop', 'Indie Rock']}
# {'id_alb': 191, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 192, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Beat']}
# {'id_alb': 193, 'gen': 'Electronic', 'genres': ['Electronic', 'Hip Hop', 'Jazz', 'Funk / Soul'], 'subgenrse': ['Acid House', 'Gangsta', 'Electro', 'Pop Rap']}
# {'id_alb': 194, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 195, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Grunge']}
# {'id_alb': 196, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Rock'], 'subgenrse': ['Alternative Rock', 'Funk Metal', 'Hardcore Hip-Hop', 'Conscious']}
# {'id_alb': 197, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 198, 'gen': 'Funk / Soul', 'genres': ['Funk / Soul'], 'subgenrse': ['Rhythm & Blues', 'Soul']}
# {'id_alb': 199, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Dance-pop']}
# {'id_alb': 200, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 201, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 202, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 203, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 204, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock', 'Latin', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 205, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 206, 'gen': 'Electronic', 'genres': ['Electronic', 'Hip Hop', 'Latin', 'Pop'], 'subgenrse': ['RnB/Swing', 'House', 'Flamenco', 'Hip Hop']}
# {'id_alb': 207, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Euro-Disco']}
# {'id_alb': 208, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Acoustic', 'Pop Rock', 'Country Rock']}
# {'id_alb': 209, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 210, 'gen': 'Rock', 'genres': ['Rock', 'Reggae', 'Funk / Soul'], 'subgenrse': ['Reggae', 'Contemporary', 'Rocksteady', 'Roots Reggae', 'Ska', 'Acoustic', 'Soul']}
# {'id_alb': 211, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Classic Rock']}
# {'id_alb': 212, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 213, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock', 'Punk']}
# {'id_alb': 214, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['AOR', 'Classic Rock']}
# {'id_alb': 215, 'gen': 'Electronic', 'genres': ['Electronic', 'Hip Hop', 'Pop'], 'subgenrse': ['Indie Pop']}
# {'id_alb': 216, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Pop Rock']}
# {'id_alb': 217, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 218, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Funk / Soul', 'Pop'], 'subgenrse': ['Contemporary R&B']}
# {'id_alb': 219, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock']}
# {'id_alb': 220, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock', 'Indie Rock']}
# {'id_alb': 221, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Pop Rock', 'Ballad']}
# {'id_alb': 222, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal', 'Power Metal']}
# {'id_alb': 223, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Folk Rock']}
# {'id_alb': 224, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 225, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Funk / Soul', 'Folk, World, & Country'], 'subgenrse': ['Flamenco', 'Funk']}
# {'id_alb': 226, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 227, 'gen': 'Electronic', 'genres': ['Electronic', 'Reggae', 'Pop'], 'subgenrse': ['Euro House', 'Europop', 'Reggae-Pop']}
# {'id_alb': 228, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 229, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Downtempo', 'Disco']}
# {'id_alb': 230, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 231, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 232, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['New Wave', 'Punk']}
# {'id_alb': 233, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Prog Rock', 'Classic Rock', 'Pop Rock']}
# {'id_alb': 234, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 235, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll', 'Psychedelic Rock']}
# {'id_alb': 236, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 237, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 238, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 239, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 240, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Vocal', 'Ballad', 'Pop Rock']}
# {'id_alb': 241, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': ['Europop']}
# {'id_alb': 242, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 243, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['House', 'Euro House', 'Disco']}
# {'id_alb': 244, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': ['Ballad', 'Vocal']}
# {'id_alb': 245, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 246, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 247, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 248, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 249, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': ['Alternative Rock', 'Folk Rock']}
# {'id_alb': 250, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 251, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Synth-pop', 'Alternative Rock', 'Punk']}
# {'id_alb': 252, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 253, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk', 'Melodic Hardcore']}
# {'id_alb': 254, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 255, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Soft Rock', 'Pop Rock']}
# {'id_alb': 256, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 257, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Alternative Rock', 'Chanson']}
# {'id_alb': 258, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock', 'Indie Rock']}
# {'id_alb': 259, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 260, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 261, 'gen': 'Rock', 'genres': ['Rock', 'Classical', 'Folk, World, & Country'], 'subgenrse': ['Art Rock']}
# {'id_alb': 262, 'gen': 'Funk / Soul', 'genres': ['Funk / Soul', 'Pop'], 'subgenrse': ['Vocal']}
# {'id_alb': 263, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 264, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 265, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Acoustic', 'Pop Rock']}
# {'id_alb': 266, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Brit Pop', 'Indie Rock']}
# {'id_alb': 267, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Prog Rock', 'Heavy Metal']}
# {'id_alb': 268, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Brit Pop']}
# {'id_alb': 269, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 270, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Rock & Roll', 'Blues Rock']}
# {'id_alb': 271, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Soft Rock']}
# {'id_alb': 272, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Grunge']}
# {'id_alb': 273, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': ['Flamenco']}
# {'id_alb': 274, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 275, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 276, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 277, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 278, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Soft Rock', 'Ballad', 'Synth-pop']}
# {'id_alb': 279, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['New Wave', 'Pop Rock', 'Post-Punk']}
# {'id_alb': 280, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Beat']}
# {'id_alb': 281, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['New Wave', 'Punk']}
# {'id_alb': 282, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 283, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Ska']}
# {'id_alb': 284, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll']}
# {'id_alb': 285, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Pop'], 'subgenrse': ['Pop Rap', 'Conscious']}
# {'id_alb': 286, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 287, 'gen': 'Electronic', 'genres': ['Electronic', 'Hip Hop', 'Rock', 'Reggae', 'Funk / Soul', 'Blues'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 288, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Gothic Metal']}
# {'id_alb': 289, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 290, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 291, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 292, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Punk']}
# {'id_alb': 293, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Prog Rock', 'Art Rock']}
# {'id_alb': 294, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Ska']}
# {'id_alb': 295, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Folk Rock', 'Alternative Rock']}
# {'id_alb': 296, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 297, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 298, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Heavy Metal']}
# {'id_alb': 299, 'gen': 'Electronic', 'genres': ['Electronic', 'Funk / Soul'], 'subgenrse': ['Contemporary R&B', 'Electro']}
# {'id_alb': 300, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 301, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Hard Rock', 'Arena Rock', 'Ballad', 'Pop Rock']}
# {'id_alb': 302, 'gen': 'Rock', 'genres': ['Rock', 'Funk / Soul'], 'subgenrse': ['New Wave', 'Pop Rock', 'Soul', 'Rhythm & Blues']}
# {'id_alb': 303, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 304, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Hi NRG', 'Disco']}
# {'id_alb': 305, 'gen': 'Jazz', 'genres': ['Jazz', 'Rock', 'Folk, World, & Country'], 'subgenrse': ['Folk Rock', 'Psychedelic Rock']}
# {'id_alb': 306, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Speed Metal', 'Heavy Metal']}
# {'id_alb': 307, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['AOR']}
# {'id_alb': 308, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Folk Rock', 'Pachanga', 'Southern Rock', 'Rumba', 'Acoustic', 'Flamenco']}
# {'id_alb': 309, 'gen': 'Blues', 'genres': ['Blues', 'Pop'], 'subgenrse': ['Doo Wop', 'Rhythm & Blues', 'Vocal']}
# {'id_alb': 310, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 311, 'gen': 'Funk / Soul', 'genres': ['Funk / Soul'], 'subgenrse': ['Soul']}
# {'id_alb': 312, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock']}
# {'id_alb': 313, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': ['Acoustic', 'Pop Rock']}
# {'id_alb': 314, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 315, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 316, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['Soft Rock', 'Synth-pop']}
# {'id_alb': 317, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 318, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Prog Rock', 'Symphonic Rock']}
# {'id_alb': 319, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk', 'Alternative Rock', 'Pop Punk']}
# {'id_alb': 320, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Soft Rock', 'Pop Rock']}
# {'id_alb': 321, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 322, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 323, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 324, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 325, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 326, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 327, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 328, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 329, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': ['Rumba']}
# {'id_alb': 330, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']}
# {'id_alb': 331, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 332, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock']}
# {'id_alb': 333, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 334, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Indie Rock', 'Shoegaze', 'Noise']}
# {'id_alb': 335, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Alternative Rock', 'Shoegaze']}
# {'id_alb': 336, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 337, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 338, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Synth-pop']}
# {'id_alb': 339, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Soft Rock', 'Pop Rock', 'Vocal']}
# {'id_alb': 340, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 341, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 342, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['House', 'Synth-pop']}
# {'id_alb': 343, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Acoustic']}
# {'id_alb': 344, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 345, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 346, 'gen': 'Reggae', 'genres': ['Reggae', 'Pop'], 'subgenrse': []}
# {'id_alb': 347, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Rock & Roll']}
# {'id_alb': 348, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Ballad']}
# {'id_alb': 349, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Alternative Rock']}
# {'id_alb': 350, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 351, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Alternative Rock', 'Soft Rock']}
# {'id_alb': 352, 'gen': 'Electronic', 'genres': ['Electronic', 'Latin', 'Pop'], 'subgenrse': ['Europop', 'Synth-pop']}
# {'id_alb': 353, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']}
# {'id_alb': 354, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 355, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 356, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Indie Pop', 'Folk Rock']}
# {'id_alb': 357, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 358, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 359, 'gen': 'Funk / Soul', 'genres': ['Funk / Soul'], 'subgenrse': ['Disco', 'Reggae-Pop']}
# {'id_alb': 360, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 361, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': ['Europop']}
# {'id_alb': 362, 'gen': 'Electronic', 'genres': ['Electronic', 'Funk / Soul', 'Pop'], 'subgenrse': ['Contemporary R&B', 'Ballad', 'House']}
# {'id_alb': 363, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Europop', 'Brit Pop', 'Pop Rock']}
# {'id_alb': 364, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Country Rock']}
# {'id_alb': 365, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Synth-pop', 'Pop Rock']}
# {'id_alb': 366, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 367, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Soft Rock', 'Pop Rock']}
# {'id_alb': 368, 'gen': 'Jazz', 'genres': ['Jazz'], 'subgenrse': ['Post Bop']}
# {'id_alb': 369, 'gen': 'Electronic', 'genres': ['Electronic', 'Hip Hop', 'Rock', 'Funk / Soul'], 'subgenrse': ['Pop Rap', 'Pop Rock', 'Disco', 'Contemporary R&B']}
# {'id_alb': 370, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Speed Metal', 'Heavy Metal', 'Power Metal']}
# {'id_alb': 371, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Prog Rock']}
# {'id_alb': 372, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 373, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 374, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 375, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': ['Folk Rock', 'Celtic', 'Punk']}
# {'id_alb': 376, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 377, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal', 'Power Metal']}
# {'id_alb': 378, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': ['Ballad', 'Bolero', 'Vocal']}
# {'id_alb': 379, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Rock', 'Pop'], 'subgenrse': ['RnB/Swing']}
# {'id_alb': 380, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 381, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock', 'Prog Rock']}
# {'id_alb': 382, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock']}
# {'id_alb': 383, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Rock', 'Latin'], 'subgenrse': ['Alternative Rock', 'Ska']}
# {'id_alb': 384, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 385, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 386, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Interview', 'Pop Rock']}
# {'id_alb': 387, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Alternative Rock']}
# {'id_alb': 388, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': ['Pop Rock', 'Rumba']}
# {'id_alb': 389, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 390, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Soft Rock']}
# {'id_alb': 391, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': ['Country', 'Rockabilly']}
# {'id_alb': 392, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': []}
# {'id_alb': 393, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Acoustic', 'Pop Rock', 'Rockabilly']}
# {'id_alb': 394, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Blues Rock']}
# {'id_alb': 395, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 396, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll']}
# {'id_alb': 397, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 398, 'gen': 'Hip Hop', 'genres': ['Hip Hop'], 'subgenrse': ['Ragga HipHop']}
# {'id_alb': 399, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 400, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Soft Rock']}
# {'id_alb': 401, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Funk / Soul', 'Pop'], 'subgenrse': ['Pop Rap']}
# {'id_alb': 402, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 403, 'gen': 'Rock', 'genres': ['Rock', 'Blues', 'Folk, World, & Country'], 'subgenrse': ['Folk Rock']}
# {'id_alb': 404, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Country Rock']}
# {'id_alb': 405, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Arena Rock', 'Pop Rock']}
# {'id_alb': 406, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 407, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Speed Metal', 'Heavy Metal']}
# {'id_alb': 408, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 409, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 410, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'New Wave', 'Shoegaze', 'Pop Rock']}
# {'id_alb': 411, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 412, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock']}
# {'id_alb': 413, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Acoustic']}
# {'id_alb': 414, 'gen': 'Rock', 'genres': ['Rock', 'Reggae', 'Funk / Soul', 'Non-Music', 'Pop'], 'subgenrse': ['Interview', 'Europop']}
# {'id_alb': 415, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 416, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 417, 'gen': 'Latin', 'genres': ['Latin', 'Folk, World, & Country'], 'subgenrse': ['Bolero', 'Ranchera']}
# {'id_alb': 418, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock', 'Punk']}
# {'id_alb': 419, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['Pop Rock', 'Downtempo', 'Synth-pop']}
# {'id_alb': 420, 'gen': 'Rock', 'genres': ['Rock', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Folk Rock', 'Pop Rock']}
# {'id_alb': 421, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 422, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Soft Rock']}
# {'id_alb': 423, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Pop Rock']}
# {'id_alb': 424, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 425, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 426, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 427, 'gen': 'Blues', 'genres': ['Blues', 'Pop'], 'subgenrse': ['Ballad']}
# {'id_alb': 428, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Country Rock', 'Soft Rock']}
# {'id_alb': 429, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 430, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 431, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 432, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 433, 'gen': 'Jazz', 'genres': ['Jazz', 'Rock'], 'subgenrse': ['Lounge', 'Parody']}
# {'id_alb': 434, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 435, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 436, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Punk']}
# {'id_alb': 437, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 438, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Bubblegum']}
# {'id_alb': 439, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Big Beat']}
# {'id_alb': 440, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 441, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 442, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Acoustic', 'Pop Rock']}
# {'id_alb': 443, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 444, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rock & Roll']}
# {'id_alb': 445, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 446, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 447, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 448, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Ska', 'Punk']}
# {'id_alb': 449, 'gen': 'Latin', 'genres': ['Latin', 'Folk, World, & Country'], 'subgenrse': ['Nueva Cancion', 'Folk']}
# {'id_alb': 450, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Ska']}
# {'id_alb': 451, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 452, 'gen': 'Jazz', 'genres': ['Jazz', 'Reggae'], 'subgenrse': ['Ska', 'Swing']}
# {'id_alb': 453, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': []}
# {'id_alb': 454, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Garage Rock', 'Pop Rock']}
# {'id_alb': 455, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 456, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 457, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Acoustic', 'Pop Rock']}
# {'id_alb': 458, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Alternative Rock', 'Vocal']}
# {'id_alb': 459, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Hard Rock']}
# {'id_alb': 460, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['Symphonic Rock', 'Prog Rock', 'AOR', 'Synth-pop']}
# {'id_alb': 461, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock']}
# {'id_alb': 462, 'gen': 'Pop', 'genres': ['Pop', 'Folk, World, & Country', 'Stage & Screen'], 'subgenrse': ['Vocal']}
# {'id_alb': 463, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Southern Rock', 'Hard Rock', 'Glam']}
# {'id_alb': 464, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Glam']}
# {'id_alb': 465, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Arena Rock', 'Hard Rock']}
# {'id_alb': 466, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Pop Rock', 'Classic Rock', 'Arena Rock', 'Rock Opera']}
# {'id_alb': 467, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 468, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 469, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Southern Rock']}
# {'id_alb': 470, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 471, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 472, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Heavy Metal']}
# {'id_alb': 473, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Glam']}
# {'id_alb': 474, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 475, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal', 'Glam']}
# {'id_alb': 476, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Heavy Metal']}
# {'id_alb': 477, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 478, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 479, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 480, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 481, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 482, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Heavy Metal']}
# {'id_alb': 483, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 484, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 485, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 486, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock', 'Glam']}
# {'id_alb': 487, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 488, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 489, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Arena Rock', 'Pop Rock', 'AOR']}
# {'id_alb': 490, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock', 'Hard Rock']}
# {'id_alb': 491, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 492, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Glam', 'Hard Rock']}
# {'id_alb': 493, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Glam', 'Hard Rock']}
# {'id_alb': 494, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 495, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 496, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 497, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Synth-pop']}
# {'id_alb': 498, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock', 'Classic Rock']}
# {'id_alb': 499, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Nu Metal']}
# {'id_alb': 500, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 501, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 502, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 503, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Country Rock']}
# {'id_alb': 504, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 505, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 506, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Power Pop', 'Rock & Roll']}
# {'id_alb': 507, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 508, 'gen': 'Electronic', 'genres': ['Electronic', 'Folk, World, & Country'], 'subgenrse': ['Latin', 'Downtempo']}
# {'id_alb': 509, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Europop', 'Downtempo', 'Euro House', 'Eurodance']}
# {'id_alb': 510, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock', 'Punk', 'Ska']}
# {'id_alb': 511, 'gen': 'Funk / Soul', 'genres': ['Funk / Soul'], 'subgenrse': ['Disco', 'Funk', 'Soul']}
# {'id_alb': 512, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Euro House']}
# {'id_alb': 513, 'gen': 'Folk, World, & Country', 'genres': ['Folk, World, & Country'], 'subgenrse': ['Flamenco']}
# {'id_alb': 514, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk', 'Pop Rock']}
# {'id_alb': 515, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 516, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 517, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 518, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 519, 'gen': 'Pop', 'genres': ['Pop', 'Folk, World, & Country'], 'subgenrse': ['Folk']}
# {'id_alb': 520, 'gen': 'Jazz', 'genres': ['Jazz', 'Funk / Soul', 'Pop'], 'subgenrse': ['Contemporary R&B', 'Soul', 'Ballad', 'Smooth Jazz', 'Easy Listening']}
# {'id_alb': 521, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Funk / Soul', 'Pop'], 'subgenrse': ['Dance-pop', 'Pop Rap', 'Contemporary R&B']}
# {'id_alb': 522, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Reggae', 'Latin'], 'subgenrse': ['Reggae', 'Latin', 'Hip Hop']}
# {'id_alb': 523, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 524, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Downtempo']}
# {'id_alb': 525, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 526, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 527, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 528, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Folk Rock']}
# {'id_alb': 529, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': ['Rumba']}
# {'id_alb': 530, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Acid Jazz', 'Downtempo']}
# {'id_alb': 531, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['New Wave', 'Pop Rock']}
# {'id_alb': 532, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['House', 'Techno', 'Downtempo', 'Ambient', 'Dance-pop']}
# {'id_alb': 533, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Soft Rock']}
# {'id_alb': 534, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 535, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Hard Rock']}
# {'id_alb': 536, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 537, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': ['Bolero']}
# {'id_alb': 538, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Vocal']}
# ...
# {'id_alb': 4094, 'gen': 'Electronic', 'genres': ['Electronic', 'Latin', 'Pop'], 'subgenrse': ['Hi NRG']}
# {'id_alb': 4095, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 4096, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 4097, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 4098, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk']}
# {'id_alb': 4099, 'gen': 'Folk, World, & Country', 'genres': ['Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4100, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal', 'Parody']}
# {'id_alb': 4101, 'gen': 'Electronic', 'genres': ['Electronic', 'Hip Hop', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Flamenco', 'Electro', 'Trap']}
# {'id_alb': 4102, 'gen': 'Reggae', 'genres': ['Reggae', 'Latin', 'Folk, World, & Country'], 'subgenrse': ['Ska']}
# {'id_alb': 4103, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4104, 'gen': 'Latin', 'genres': ['Latin', 'Folk, World, & Country'], 'subgenrse': ['Flamenco']}
# {'id_alb': 4105, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Thrash', 'Hardcore']}
# {'id_alb': 4106, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 4107, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['Pop Rock', 'Synth-pop']}
# {'id_alb': 4108, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Ballad', 'Synth-pop', 'Latin', 'Ambient']}
# {'id_alb': 4109, 'gen': 'Folk, World, & Country', 'genres': ['Folk, World, & Country'], 'subgenrse': ['Rumba', 'Flamenco']}
# {'id_alb': 4110, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4111, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Rockabilly']}
# {'id_alb': 4112, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': ['Ballad']}
# {'id_alb': 4113, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 4114, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Synth-pop', 'House']}
# {'id_alb': 4115, 'gen': 'Latin', 'genres': ['Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 4116, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Karaoke']}
# {'id_alb': 4117, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Heavy Metal']}
# {'id_alb': 4118, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Chanson', 'Yé-Yé']}
# {'id_alb': 4119, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 4120, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Alternative Rock', 'Indie Pop']}
# {'id_alb': 4121, 'gen': 'Folk, World, & Country', 'genres': ['Folk, World, & Country'], 'subgenrse': ['Country']}
# {'id_alb': 4122, 'gen': 'Folk, World, & Country', 'genres': ['Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4123, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4124, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Electro', 'Synth-pop']}
# {'id_alb': 4125, 'gen': 'Pop', 'genres': ['Pop', 'Folk, World, & Country'], 'subgenrse': ['Chanson']}
# {'id_alb': 4126, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4127, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Grunge', 'Pop Rock']}
# {'id_alb': 4128, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 4129, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 4130, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4131, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Indie Pop']}
# {'id_alb': 4132, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 4133, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 4134, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4135, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Psychedelic Rock', 'Classic Rock', 'Dream Pop', 'Folk Rock', 'Soft Rock', 'Trip Hop', 'Ballad']}
# {'id_alb': 4136, 'gen': 'Pop', 'genres': ['Pop', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4137, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Indie Pop']}
# {'id_alb': 4138, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 4139, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4140, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': ['Folk']}
# {'id_alb': 4141, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4142, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Experimental', 'Ambient', 'New Age']}
# {'id_alb': 4143, 'gen': 'Rock', 'genres': ['Rock', 'Funk / Soul'], 'subgenrse': ['Soul']}
# {'id_alb': 4144, 'gen': 'Pop', 'genres': ['Pop', 'Brass & Military'], 'subgenrse': []}
# {'id_alb': 4145, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4146, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4147, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Indie Pop']}
# {'id_alb': 4148, 'gen': 'Blues', 'genres': ['Blues', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4149, 'gen': 'Jazz', 'genres': ['Jazz', 'Rock', 'Funk / Soul'], 'subgenrse': ['Ska', 'Punk', 'Funk']}
# {'id_alb': 4150, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Punk', 'Pop Rock']}
# {'id_alb': 4151, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4152, 'gen': 'Rock', 'genres': ['Rock', 'Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 4153, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Experimental', 'Prog Rock']}
# {'id_alb': 4154, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Art Rock']}
# {'id_alb': 4155, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 4156, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4158, 'gen': 'Reggae', 'genres': ['Reggae'], 'subgenrse': ['Ska']}
# {'id_alb': 4159, 'gen': 'Reggae', 'genres': ['Reggae'], 'subgenrse': ['Ska']}
# {'id_alb': 4160, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4161, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Surf', 'Punk']}
# {'id_alb': 4162, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Doom Metal']}
# {'id_alb': 4163, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock', 'Prog Rock', 'Symphonic Rock']}
# {'id_alb': 4164, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Funk / Soul'], 'subgenrse': ['Contemporary R&B', 'Soul']}
# {'id_alb': 4165, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['House', 'Deep House']}
# {'id_alb': 4166, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['House', 'Garage House', 'UK Garage']}
# {'id_alb': 4167, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 4168, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Mod', 'Beat', 'Psychedelic Rock']}
# {'id_alb': 4169, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Deep House', 'Tropical House']}
# {'id_alb': 4170, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Deep House']}
# {'id_alb': 4171, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4176, 'gen': 'Folk, World, & Country', 'genres': ['Folk, World, & Country'], 'subgenrse': ['Folk', 'Celtic']}
# {'id_alb': 4177, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['Alternative Rock', 'Prog Rock']}
# {'id_alb': 4178, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Avantgarde', 'Experimental', 'Prog Rock']}
# {'id_alb': 4179, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['Abstract', 'Psychedelic Rock', 'Experimental', 'Prog Rock']}
# {'id_alb': 4180, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock', 'Funk / Soul', 'Pop'], 'subgenrse': ['Indie Pop', 'Pop Rock', 'Ballad', 'Downtempo']}
# {'id_alb': 4181, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4182, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['New Wave']}
# {'id_alb': 4183, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['New Wave', 'Synth-pop', 'Disco']}
# {'id_alb': 4184, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['New Wave', 'Pop Rock']}
# {'id_alb': 4185, 'gen': 'Latin', 'genres': ['Latin', 'Folk, World, & Country'], 'subgenrse': ['Flamenco']}
# {'id_alb': 4186, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Indie Rock']}
# {'id_alb': 4187, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 4188, 'gen': 'Hip Hop', 'genres': ['Hip Hop'], 'subgenrse': []}
# {'id_alb': 4189, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': ['Indie Rock', 'Folk']}
# {'id_alb': 4190, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': ['Indie Rock', 'Folk']}
# {'id_alb': 4192, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Flamenco', 'Vocal']}
# {'id_alb': 4193, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Latin', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4194, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4195, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Latin', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4196, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4197, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Soft Rock', 'Vocal', 'Ballad']}
# {'id_alb': 4199, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock', 'Pop'], 'subgenrse': ['Dance-pop', 'Europop', 'Pop Rock', 'Bubblegum', 'Power Pop']}
# {'id_alb': 4200, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Ballad', 'Pop Rock']}
# {'id_alb': 4201, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4202, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4203, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock', 'Ballad']}
# {'id_alb': 4206, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Pop'], 'subgenrse': []}
# {'id_alb': 4207, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Pop'], 'subgenrse': []}
# {'id_alb': 4208, 'gen': 'Rock', 'genres': ['Rock', 'Pop', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4209, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 4210, 'gen': 'Rock', 'genres': ['Rock', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Alternative Rock', 'Indie Rock', 'Indie Pop', 'Folk']}
# {'id_alb': 4211, 'gen': 'Latin', 'genres': ['Latin', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Folk', 'Vocal']}
# {'id_alb': 4212, 'gen': 'Electronic', 'genres': ['Electronic', 'Reggae', 'Latin', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Reggaeton', 'Ballad', 'Batucada', 'Fado', 'Dance-pop', 'Trap', 'House', 'Reggae-Pop', 'Dancehall']}
# {'id_alb': 4213, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Trap', 'Indie Pop']}
# {'id_alb': 4214, 'gen': 'Rock', 'genres': ['Rock', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Folk Rock', 'Alternative Rock']}
# {'id_alb': 4215, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Acoustic']}
# {'id_alb': 4216, 'gen': 'Jazz', 'genres': ['Jazz', 'Latin', 'Folk, World, & Country'], 'subgenrse': ['Fusion', 'Flamenco', 'Tango']}
# {'id_alb': 4219, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4220, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock'], 'subgenrse': ['Latin', 'Pop Rock']}
# {'id_alb': 4221, 'gen': 'Rock', 'genres': ['Rock', 'Latin'], 'subgenrse': []}
# {'id_alb': 4222, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4223, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 4224, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4225, 'gen': 'Pop', 'genres': ['Pop', 'Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4226, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': []}
# {'id_alb': 4227, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 4228, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 4229, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Blues Rock', 'Punk']}
# {'id_alb': 4230, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Blues Rock', 'Punk']}
# {'id_alb': 4232, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 4233, 'gen': 'Electronic', 'genres': ['Electronic', 'Classical'], 'subgenrse': ['Electro', 'Classical', 'Experimental']}
# {'id_alb': 4235, 'gen': 'Jazz', 'genres': ['Jazz'], 'subgenrse': ['Smooth Jazz']}
# {'id_alb': 4236, 'gen': 'Jazz', 'genres': ['Jazz'], 'subgenrse': ['Smooth Jazz']}
# {'id_alb': 4237, 'gen': 'Jazz', 'genres': ['Jazz', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Vocal']}
# {'id_alb': 4239, 'gen': 'Electronic', 'genres': ['Electronic', 'Hip Hop', 'Latin', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Flamenco', 'Pasodoble', 'Bossanova']}
# {'id_alb': 4240, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 4241, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Blues Rock', 'Folk Rock', 'Classic Rock']}
# {'id_alb': 4242, 'gen': 'Latin', 'genres': ['Latin'], 'subgenrse': []}
# {'id_alb': 4243, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['New Wave']}
# {'id_alb': 4244, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Alternative Rock']}
# {'id_alb': 4245, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Pop Rock']}
# {'id_alb': 4246, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Chanson', 'Ballad']}
# {'id_alb': 4249, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Latin', 'Pop'], 'subgenrse': ['Reggaeton', 'RnB/Swing']}
# {'id_alb': 4250, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4252, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Latin', 'Pop'], 'subgenrse': []}
# {'id_alb': 4253, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Jazz', 'Latin', 'Funk / Soul', 'Pop'], 'subgenrse': ['Contemporary R&B', 'Latin Jazz', 'Neo Soul', 'Salsa', 'Tango']}
# {'id_alb': 4254, 'gen': 'Hip Hop', 'genres': ['Hip Hop', 'Latin', 'Funk / Soul'], 'subgenrse': []}
# {'id_alb': 4255, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4256, 'gen': 'Jazz', 'genres': ['Jazz', 'Pop'], 'subgenrse': []}
# {'id_alb': 4257, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4258, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': []}
# {'id_alb': 4260, 'gen': 'Electronic', 'genres': ['Electronic', 'Hip Hop', 'Classical', 'Folk, World, & Country'], 'subgenrse': ['Experimental']}
# {'id_alb': 4261, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4262, 'gen': 'Electronic', 'genres': ['Electronic'], 'subgenrse': ['Synth-pop', 'Acid House']}
# {'id_alb': 4263, 'gen': 'Electronic', 'genres': ['Electronic', 'Pop'], 'subgenrse': ['Synth-pop']}
# {'id_alb': 4264, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4266, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Glam', 'Punk', 'Heavy Metal']}
# {'id_alb': 4267, 'gen': nan, 'genres': nan, 'subgenrse': nan}
# {'id_alb': 4268, 'gen': 'Stage & Screen', 'genres': ['Stage & Screen'], 'subgenrse': ['Soundtrack', 'Score']}
# {'id_alb': 4269, 'gen': 'Rock', 'genres': ['Rock', 'Pop', 'Folk, World, & Country'], 'subgenrse': ['Folk Rock', 'Pop Rock', 'Alternative Rock', 'Indie Rock', 'Lo-Fi']}
# {'id_alb': 4270, 'gen': 'Folk, World, & Country', 'genres': ['Folk, World, & Country'], 'subgenrse': ['Folk']}
# {'id_alb': 4271, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock', 'Indie Rock']}
# {'id_alb': 4272, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': []}
# {'id_alb': 4273, 'gen': 'Folk, World, & Country', 'genres': ['Folk, World, & Country'], 'subgenrse': []}
# {'id_alb': 4274, 'gen': 'Rock', 'genres': ['Rock', 'Pop'], 'subgenrse': ['Folk Rock', 'Acoustic', 'Pop Rock']}
# {'id_alb': 4275, 'gen': 'Rock', 'genres': ['Rock', 'Folk, World, & Country'], 'subgenrse': ['Folk Rock', 'Folk']}
# {'id_alb': 4276, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Folk Rock']}
# {'id_alb': 4278, 'gen': 'Rock', 'genres': ['Rock'], 'subgenrse': ['Classic Rock', 'Rock & Roll', 'Blues Rock']}
# {'id_alb': 4279, 'gen': 'Pop', 'genres': ['Pop'], 'subgenrse': ['Ballad']}
# {'id_alb': 4280, 'gen': 'Electronic', 'genres': ['Electronic', 'Rock', 'Pop'], 'subgenrse': ['New Wave', 'Pop Rock', 'Synth-pop']}

# %%
albums_genero.to_csv('../output/albums_genero.csv',index=False)
#4258

# %%
url = f'https://api.discogs.com/database/search?artist={r.art_url}&release_title={r.alb_url}&token={tokendis}'
req = requests.get(url).json()

# %%
req
# Out:
# {'pagination': {'page': 1,
#   'pages': 2,
#   'per_page': 50,
#   'items': 56,
#   'urls': {'last': 'https://api.discogs.com/database/search?artist=Cutting+Crew&release_title=Broadcast&token=WrCeBqUsvvoWPGbIAnhkioHGnehnEzAIPErEWxLI&page=2&per_page=50',
#    'next': 'https://api.discogs.com/database/search?artist=Cutting+Crew&release_title=Broadcast&token=WrCeBqUsvvoWPGbIAnhkioHGnehnEzAIPErEWxLI&page=2&per_page=50'}},
#  'results': [{'country': 'UK',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album', 'Stereo'],
#    'label': ['Siren',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.',
#     'Chipping Norton Recording Studios',
#     'Mediasound',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Tape One'],
#    'type': 'master',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['New Wave', 'Pop Rock', 'Synth-pop'],
#    'id': 65301,
#    'barcode': ['5 012983 500717',
#     '5012983500717',
#     'SIRENLP 7 A-1U-1-1-1 Bilbo.Tape One',
#     'SIRENLP 7 B-1U-1-1-2 Bilbo.Tape One',
#     'SIRENLP 7 A-1U-1-3 BilBo.Tape One',
#     'SIRENLP 7 B-1U-1-3 BilBo.Tape One',
#     'SIRENLP 7 A-1U-1-1-1 Bilbo.Tape One',
#     'SIRENLP 7 B-1U-1-2-X1 BilBo.Tape One',
#     'SIRENLP 7 A-1U-1-2- Bilbo.Tape One',
#     'SIRENLP 7 B-1U-1-4- BilBo.Tape One'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/master/65301-Cutting-Crew-Broadcast',
#    'catno': 'SIREN LP 7',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/IUfRuFUU5RlmV1mVMX6xyV_hY_4o4gnfI4ovfukA2kM/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/MjQ2NDktMTM0NzMy/NTYxMC0zMjg1Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/0YWpgg86hnzEOLnculQvl8gjXvDjAaCoSGRV8-baRC4/rs:fit/g:sm/q:90/h:454/w:454/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/MjQ2NDktMTM0NzMy/NTYxMC0zMjg1Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/masters/65301',
#    'community': {'want': 2254, 'have': 6844}},
#   {'country': 'UK',
#    'year': '1992',
#    'format': ['CD', 'Album', 'Reissue', 'Stereo'],
#    'label': ['Siren', 'Virgin'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['AOR', 'Synth-pop', 'Pop Rock'],
#    'id': 10146534,
#    'barcode': ['0 77778 60022 0',
#     'LC 3098',
#     '786002 2 . 1 EMI SWINDON',
#     'PM 500',
#     'AAD',
#     'B.I.E.M./STEMRA',
#     'UK: CDSRN 7'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/10146534-Cutting-Crew-Broadcast',
#    'catno': 'CDSRN 7',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/BFGb5MuQNcRHgmi4wJnlk4olSEl5fcjSDCqSVt3y8mo/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEw/MTQ2NTM0LTE0OTI0/Mzc1NjEtOTc0MC5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/EE4q9L3f5SU-VCTfDKnYPj4c29ObIKhLC9-R1-II59I/rs:fit/g:sm/q:90/h:200/w:200/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEw/MTQ2NTM0LTE0OTI0/Mzc1NjEtOTc0MC5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/10146534',
#    'community': {'want': 29, 'have': 64},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD',
#      'qty': '1',
#      'descriptions': ['Album', 'Reissue', 'Stereo']}]},
#   {'country': 'France',
#    'year': '1986',
#    'format': ['Cassette', 'Album'],
#    'label': ['Virgin',
#     'Siren',
#     'Siren',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Comforts Place',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Tape One',
#     'Pathé Marconi S.A.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 14628680,
#    'barcode': ['5 012983 500748', 'SACEM SACD SDRM SGDL'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/14628680-Cutting-Crew-Broadcast',
#    'catno': '350 074',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/CQ98GCUFelDzrsgNs7FuH7F95Uhxqmqdp6J7hqoJkmg/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/NjI4NjgwLTE1Nzg5/MTgwNzUtMjI5OC5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/m8Gh3fS-a0qJFBKTJjLTmepN4QJ6SR9JQJQ-qhvZgc8/rs:fit/g:sm/q:90/h:802/w:528/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/NjI4NjgwLTE1Nzg5/MTgwNzUtMjI5OC5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/14628680',
#    'community': {'want': 20, 'have': 4},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette', 'qty': '1', 'descriptions': ['Album']}]},
#   {'country': 'US',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin',
#     'Virgin',
#     'Siren Records Ltd.',
#     'Virgin Records America, Inc.',
#     'Allied Record Company',
#     'Virgin-Nymph Music Inc.',
#     'Chipping Norton Recording Studios',
#     'Utopia Studios',
#     'Precision Mastering'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 4595740,
#    'barcode': ['0 7567-90573-1 0',
#     'ST-VR-866281-AR',
#     'ST-VR-866282-AR',
#     'ST-VR 866281-A DMM SP 2-2 B-26753-A-DMM Precision >15785 o- SPAR',
#     'ST-VR 866282-ADMM SP 2-3 B-26754ADMM Precision >15785-x o- SPAR',
#     'BMI'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/4595740-Cutting-Crew-Broadcast',
#    'catno': '1-90573',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/oeFfVE3um1FT0R6INYNQoelYclbvJnvVHYQzvo6t-IE/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTQ1/OTU3NDAtMTM2OTcw/OTUzMy01NzcyLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/XGdJGWD07YvkhmHq4sQCOIcjSWVFhmXQYlisR4uijxg/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTQ1/OTU3NDAtMTM2OTcw/OTUzMy01NzcyLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/4595740',
#    'community': {'want': 100, 'have': 605},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'text': 'Allied Pressing',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'South Korea',
#    'year': '1987',
#    'format': ['Cassette', 'Album'],
#    'label': ['Yeh Eum Records',
#     'Siren',
#     'Virgin',
#     'Yeh Eum Records Co., Ltd.',
#     'Virgin Records Ltd.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 14919955,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/14919955-Cutting-Crew-Broadcast',
#    'catno': 'YVPC 125',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/Qxzfvd6lWtG4yFdNPFG_N3-qDSyMx0ZBkWEf2VFrj18/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/OTE5OTU1LTE1ODQx/MDQzNTctNTI3NS5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/hu0QmL1PmhRC3qHDUuVrKcJI-GFFuZmabKPD9npcz7E/rs:fit/g:sm/q:90/h:924/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/OTE5OTU1LTE1ODQx/MDQzNTctNTI3NS5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/14919955',
#    'community': {'want': 15, 'have': 4},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette',
#      'qty': '1',
#      'text': 'Slipcase ',
#      'descriptions': ['Album']}]},
#   {'country': 'US',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin',
#     'Virgin',
#     'Siren Records Ltd.',
#     'Virgin Records America, Inc.',
#     'Specialty Records Corporation',
#     'Virgin-Nymph Music Inc.',
#     'Chipping Norton Recording Studios',
#     'Utopia Studios',
#     'Precision Mastering'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 1509509,
#    'barcode': ['0 7567-90573-1 0',
#     'ST-VR-866281-SP',
#     'ST-VR-866282-SP',
#     'ST-VR 866281-A DMM SP 1-2 Precision',
#     'ST-VR 866282-ADMM SP 2-2 Precision',
#     'ST-VR 866281-A DMM SP 1-2 Precision',
#     'ST-VR 866282-ADMM SP 2-1 Precision',
#     'BMI'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/1509509-Cutting-Crew-Broadcast',
#    'catno': '1-90573',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/oTUWmIpLbM0-hTOsZvShMMjdZTXfy1xRyl1yHMLUZn8/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE1/MDk1MDktMTI2NTk3/NjQ2NC5qcGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/hviogBFV9Oxy0eBxRxwTgNXmjYJfMu8dB02dVCQ6USA/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE1/MDk1MDktMTI2NTk3/NjQ2NC5qcGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/1509509',
#    'community': {'want': 135, 'have': 1203},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'text': 'Specialty Pressing',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'Europe',
#    'year': '1986',
#    'format': ['Cassette', 'Album'],
#    'label': ['Virgin',
#     'Siren',
#     'Virgin',
#     'Siren',
#     'TOPAC',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Comforts Place',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Tape One'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 2975863,
#    'barcode': ['LC 3098', 'GEMA STEMRA BIEM'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/2975863-Cutting-Crew-Broadcast',
#    'catno': '408 019',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/-mUmDn5ejPQJNT1D9aIv-gHvoVqViE4MgNnqdorgmqA/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTI5/NzU4NjMtMTMwOTk5/MjY1Ni5qcGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/HxUg7TxaIQEnShraHF4x6AkEV6qEt7N-XbZ0GQ6TRQI/rs:fit/g:sm/q:90/h:530/w:542/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTI5/NzU4NjMtMTMwOTk5/MjY1Ni5qcGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/2975863',
#    'community': {'want': 33, 'have': 31},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette', 'qty': '1', 'descriptions': ['Album']}]},
#   {'country': 'Brazil',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin', 'Virgin', 'BMG Ariola Discos Ltda.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 5501115,
#    'barcode': ['Série Bronze'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/5501115-Cutting-Crew-Broadcast',
#    'catno': '130.8012',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/3dCnuCLm6LC36Odb4N_haqrVZ1QzOvWPWDpuiDMr0iM/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTU1/MDExMTUtMTM5NzMx/MTQzNi04NDM1Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/-tNj6J5DjRlqXA32vBPpKgPBFAY17IwOOnTVdiDHIaI/rs:fit/g:sm/q:90/h:497/w:500/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTU1/MDExMTUtMTM5NzMx/MTQzNi04NDM1Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/5501115',
#    'community': {'want': 35, 'have': 21},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'Philippines',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin', 'Siren', 'Siren Records Ltd.', 'Siren Records Ltd.'],
#    'type': 'release',
#    'genre': ['Electronic'],
#    'style': ['Synth-pop'],
#    'id': 14979381,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/14979381-Cutting-Crew-Broadcast',
#    'catno': 'V-4679',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': '',
#    'cover_image': 'https://s.discogs.com/79f98959a47c003974fe784e6c38c9c35b0584ba/images/spacer.gif',
#    'resource_url': 'https://api.discogs.com/releases/14979381',
#    'community': {'want': 21, 'have': 2},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'Europe',
#    'year': '1986',
#    'format': ['CD', 'Album'],
#    'label': ['Siren', 'Siren Records Ltd.', 'Siren Records Ltd.', 'Sonopress'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Synth-pop', 'Pop Rock'],
#    'id': 4186525,
#    'barcode': ['5012983500724',
#     '5 012983 500724',
#     'AAD',
#     'SONOPRESS B6224 / CDSIREN7 A'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/4186525-Cutting-Crew-Broadcast',
#    'catno': 'CD SIREN 7',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/M-sx50GRKgcevKlOfjLhNKpq9siV3ALr4f91LQYwG20/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTQx/ODY1MjUtMTU2NzQ0/MjAyOC05MTM3Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/CQuRVVd9BeGN9bi2aoB4CMrvRZBH7rVmYrYh0CbGmf8/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTQx/ODY1MjUtMTU2NzQ0/MjAyOC05MTM3Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/4186525',
#    'community': {'want': 43, 'have': 156},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD', 'qty': '1', 'descriptions': ['Album']}]},
#   {'country': 'Europe',
#    'year': '1986',
#    'format': ['Cassette', 'Album'],
#    'label': ['Siren'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['New Wave', 'Synth-pop'],
#    'id': 15237140,
#    'barcode': ['5012983500340'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/15237140-Cutting-Crew-Broadcast',
#    'catno': 'SIREN C7',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/kUOnx5kdHnPw_kLW5jMtHGoGeIZrVdxO5I8yMet9WIk/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE1/MjM3MTQwLTE1ODg1/MDA4NzYtMjYzNi5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/pSmlX_NlRyySs3rGT4Bhr3omniKfvgk_8xNXSv3sl4s/rs:fit/g:sm/q:90/h:1066/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE1/MjM3MTQwLTE1ODg1/MDA4NzYtMjYzNi5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/15237140',
#    'community': {'want': 15, 'have': 6},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette', 'qty': '1', 'descriptions': ['Album']}]},
#   {'country': 'Europe',
#    'year': '2010',
#    'format': ['CD', 'Album', 'Reissue', 'Remastered'],
#    'label': ['Cherry Pop',
#     'Virgin Records Ltd.',
#     'Not On Label (Cutting Crew Self-released)',
#     'Cherry Pop',
#     'EMI Records Ltd.',
#     'Not On Label (Cutting Crew Self-released)',
#     'Sony DADC, Southwater'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 2813033,
#    'barcode': ['5 013929 424821',
#     '5013929424821',
#     'mcps',
#     'Sony DADC CRPOP48 03',
#     'IFPI LY34',
#     'AEW41',
#     'SonyDADC KEYPRODUCTION.CO.UK CRPROP48 41 A00',
#     'IFPI L551',
#     'IFPI 946B',
#     'Sony DADC CRPOP48 01',
#     'IFPI LY34',
#     'IFPI AEW39'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/2813033-Cutting-Crew-Broadcast',
#    'catno': 'CRPOP48',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/zNxnLQaOdA6jKYt6cjdTzyj6mxtvUA2ihGwqWx-UpBA/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTI4/MTMwMzMtMTQzOTY0/MzcyNy04OTQ0Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/WaP80UINXYDNA9kfSwLrfaYBhiq3xNKhHndvhRlZ_Ho/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTI4/MTMwMzMtMTQzOTY0/MzcyNy04OTQ0Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/2813033',
#    'community': {'want': 74, 'have': 146},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD',
#      'qty': '1',
#      'descriptions': ['Album', 'Reissue', 'Remastered']}]},
#   {'country': 'Portugal',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Siren'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Pop Rock', 'New Wave'],
#    'id': 3991961,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/3991961-Cutting-Crew-Broadcast',
#    'catno': '605423',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/PeCIZmg8oJj-SrTVjl-fEQicysJTDJ6IygCgFxKi3q4/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTM5/OTE5NjEtMTM1MTYy/NzMxMS01Nzc2Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/UvTlqmFLb6DZFR3qAv6uQgF925NhqP57O1AqE0aBG_A/rs:fit/g:sm/q:90/h:447/w:459/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTM5/OTE5NjEtMTM1MTYy/NzMxMS01Nzc2Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/3991961',
#    'community': {'want': 44, 'have': 51},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'France',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin',
#     'Virgin France S.A.',
#     'Virgin France S.A.',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Comforts Place',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Tape One',
#     'TOPAC',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 2499492,
#    'barcode': ['GEMA / STEMRA / BIEM', 'LC 3098'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/2499492-Cutting-Crew-Broadcast',
#    'catno': '350071',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/fHIgSCH3JV4RlG9f2mCvXbisF3xq91xFTW9egDEK1R4/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTI0/OTk0OTItMTQ1MDc5/MjEzMy0yMDU4Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/98rnGz3LWjPmSv-vHhfQCmeRG4im1leXa3XuTHKmHTU/rs:fit/g:sm/q:90/h:601/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTI0/OTk0OTItMTQ1MDc5/MjEzMy0yMDU4Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/2499492',
#    'community': {'want': 46, 'have': 47},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'South Africa',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Synth-pop', 'Pop Rock'],
#    'id': 8378523,
#    'barcode': ['6001211004782', 'VNC 5092 VS', 'VNC 5092 VS'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/8378523-Cutting-Crew-Broadcast',
#    'catno': 'VNC 5092',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/wSGfJrT2TOoNWSvprnzBrOQ1DCDxnkizMLGTMAN3vCY/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTgz/Nzg1MjMtMTQ2MDQ1/MzMyMy04NDgyLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/hxtr_rAw8_1rziup9gdZnEotpWHhHtRTWriSkXWXgVI/rs:fit/g:sm/q:90/h:336/w:339/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTgz/Nzg1MjMtMTQ2MDQ1/MzMyMy04NDgyLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/8378523',
#    'community': {'want': 43, 'have': 30},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'South Korea',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album', 'Stereo'],
#    'label': ['Yeh Eum Records',
#     'Siren',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.',
#     'Chipping Norton Recording Studios',
#     'Mediasound',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Tape One'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['New Wave', 'Pop Rock', 'Synth-pop'],
#    'id': 12826307,
#    'barcode': ['5 012983 500717',
#     'SIRENLP 7 A-1U-1-1-1',
#     'SIRENLP 7 B-1U-1-1-2',
#     'Bilbo.Tape One'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/12826307-Cutting-Crew-Broadcast',
#    'catno': 'YVPL 125',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/b5homrjwZKbhKE9mp6IpXspMH_dy1KvuTHOC8XreBrw/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEy/ODI2MzA3LTE1NDI2/OTkzNTYtNTY4Ny5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/jlBmifCpxsFJ6OIHOMeU4mGztsvokc8HdeGMo3jypbk/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEy/ODI2MzA3LTE1NDI2/OTkzNTYtNTY4Ny5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/12826307',
#    'community': {'want': 36, 'have': 94},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album', 'Stereo']}]},
#   {'country': 'Canada',
#    'year': '1986',
#    'format': ['Cassette', 'Album'],
#    'label': ['Virgin',
#     'Siren Records',
#     'Precision Lacquer',
#     'Siren Records',
#     'Siren Records',
#     'Virgin Records Canada Inc.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 5082659,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/5082659-Cutting-Crew-Broadcast',
#    'catno': 'VL4 2363',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/-0hb6JkOBm7MjUbU1it7_MZbiTSSwza4cxiPe2UOLgs/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTUw/ODI2NTktMTM5MTY4/NjQ1MS0xMDI4Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/V4h2EExybI-Aq4cejuwbubGXeSyNBH3_AxoOWiZ-kdg/rs:fit/g:sm/q:90/h:794/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTUw/ODI2NTktMTM5MTY4/NjQ1MS0xMDI4Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/5082659',
#    'community': {'want': 30, 'have': 26},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette',
#      'qty': '1',
#      'text': 'Chrome, Dolby',
#      'descriptions': ['Album']}]},
#   {'country': 'US',
#    'year': '1986',
#    'format': ['Cassette', 'Album'],
#    'label': ['Virgin',
#     'Virgin',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Comforts Place',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Precision Lacquer'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 19425235,
#    'barcode': ['075679057341', '0 7567-90573-4 1', 'SR'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/19425235-Cutting-Crew-Broadcast',
#    'catno': 'V4-90573',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/AH8OP8pYS6nazjpHzixHPXLRgxxuhQe5WPhoUY2gpGE/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/NDI1MjM1LTE2MjU3/NzcwNDktNTUzMy5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/fanT5RSHUuCNY-9Xh927ykWIcz0zNJ7ZfnZqOZqECww/rs:fit/g:sm/q:90/h:588/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/NDI1MjM1LTE2MjU3/NzcwNDktNTUzMy5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/19425235',
#    'community': {'want': 9, 'have': 2},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette', 'qty': '1', 'descriptions': ['Album']}]},
#   {'country': 'United Arab Emirates',
#    'year': '1986',
#    'format': ['Cassette', 'Album', 'Unofficial Release'],
#    'label': ['Thomsun Original'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 13098385,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/13098385-Cutting-Crew-Broadcast',
#    'catno': 'EN-1275',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/i37Uq4I0Y6JeURmyDfOwo8XSKgM-EKv4n-NBQSIEFgo/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEz/MDk4Mzg1LTE1NDgw/MTc1MDgtODczNS5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/O6kALEkcc10zR0vul76nW5CDf_GrhcrMjY7eQsztUdI/rs:fit/g:sm/q:90/h:949/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEz/MDk4Mzg1LTE1NDgw/MTc1MDgtODczNS5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/13098385',
#    'community': {'want': 18, 'have': 1},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette',
#      'qty': '1',
#      'descriptions': ['Album', 'Unofficial Release']}]},
#   {'country': 'US',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album', 'Club Edition'],
#    'label': ['Virgin', 'Virgin', 'Columbia House'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 5828763,
#    'barcode': ['075679057310'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/5828763-Cutting-Crew-Broadcast',
#    'catno': 'V1-90573',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/qinfd2-XZFW0kkAKjKmbKHtx7c9lbxCs6bCw5rf1nBM/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTU4/Mjg3NjMtMTQ1NDM5/NjQ2Ni0xNDQ3Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/WIbJ98DoPr5xsdFvfZnAVgrXpiHnZCWJWtav4HOLa00/rs:fit/g:sm/q:90/h:585/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTU4/Mjg3NjMtMTQ1NDM5/NjQ2Ni0xNDQ3Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/5828763',
#    'community': {'want': 52, 'have': 242},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album', 'Club Edition']}]},
#   {'country': 'Japan',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin',
#     'Siren',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.',
#     'Toshiba EMI Ltd',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Comforts Place',
#     'Tape One'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 8002608,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/8002608-Cutting-Crew-Broadcast',
#    'catno': 'VJL-28013',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/WikXiTo_WYVBO_OOrPBvc5ppMP1Q0vfVCDQ-l4B6dGI/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTgw/MDI2MDgtMTQ1MzI3/MzEwMi0zMDcyLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/ZdryiRqfgpQE3E6tiXMDfXKPrX5sXyTgJ1GyuHV0Vs4/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTgw/MDI2MDgtMTQ1MzI3/MzEwMi0zMDcyLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/8002608',
#    'community': {'want': 41, 'have': 4},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'Greece',
#    'year': '1986',
#    'format': ['Cassette'],
#    'label': ['Virgin', 'Siren Records Ltd.', 'EMI Greece', 'EMIAL S.A.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 15169600,
#    'barcode': ['AEPI'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/15169600-Cutting-Crew-Broadcast',
#    'catno': 'TC-VG 50234',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/DRDhm30kjgqST77X6UUHz0uufz3bOYLPcKA5w8To9c4/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE1/MTY5NjAwLTE1ODc1/ODc2OTYtMzQzNy5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/voB_XapWoxtR5-zBuW8Ty5mCihr7Wro82vq3VBk4-ys/rs:fit/g:sm/q:90/h:359/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE1/MTY5NjAwLTE1ODc1/ODc2OTYtMzQzNy5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/15169600',
#    'community': {'want': 14, 'have': 1},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette', 'qty': '1'}]},
#   {'country': 'US',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album', 'Club Edition'],
#    'label': ['Virgin',
#     'Virgin',
#     'BMG Direct Marketing, Inc.',
#     'BMG Direct Marketing, Inc.',
#     'Virgin Records America, Inc.',
#     'Siren Records Ltd.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Synth-pop', 'Pop Rock'],
#    'id': 6013417,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/6013417-Cutting-Crew-Broadcast',
#    'catno': '7 90573-1',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/OWJX4A-WnlZD8NIl0YU2SH1q_j4iF4hD37HS-t88g_4/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTYw/MTM0MTctMTQwODgy/MTU1MC01NDAwLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/v3raDJLIACuVDXzMbVm7-m1TEBzTIvgOQ5e8QAXtNIc/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTYw/MTM0MTctMTQwODgy/MTU1MC01NDAwLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/6013417',
#    'community': {'want': 73, 'have': 158},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album', 'Club Edition']}]},
#   {'country': 'Greece',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin',
#     'Siren',
#     'Δίσκοι Virgin ΕΠΕ',
#     'EMIAL S.A.',
#     'Siren Records Ltd.',
#     'EMI Greece',
#     'EMI Greece',
#     'Columbia, Athens'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Synth-pop', 'Pop Rock'],
#    'id': 5793621,
#    'barcode': ['V G 56234 A', 'V G 56234 B', 'AEPI', 'A/A 13523 ', 'MT 13523'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/5793621-Cutting-Crew-Broadcast',
#    'catno': 'VG 50234',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/fZZ9PorPF3fbQAyco1hYpPubOh8d2z2qr6dJrqhmrHI/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTU3/OTM2MjEtMTQ4NTI1/MTQ3Ny05NTQ2Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/Lm47alrap3JBxVkH3DYAQ8eOamNj5hFJk5HpvTEHSDA/rs:fit/g:sm/q:90/h:602/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTU3/OTM2MjEtMTQ4NTI1/MTQ3Ny05NTQ2Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/5793621',
#    'community': {'want': 42, 'have': 51},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'Australia',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin',
#     'Siren',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.',
#     'Chipping Norton Recording Studios',
#     'Mediasound',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['New Wave', 'Pop Rock', 'Synth-pop'],
#    'id': 11273969,
#    'barcode': ['5 012983 500717', 'SIREN LP7A', 'SIREN LP7B'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/11273969-Cutting-Crew-Broadcast',
#    'catno': 'SIREN LP7',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/uuocT3eZuOjip7ypfqn6ZRkyh2jqzVLfqqKWPMZPM7Q/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEx/MjczOTY5LTE1NjY3/MTY0MjYtOTA3OC5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/lANp0oizZcGdo0kL-ceUEXkhxFJgamdVqySkcnUq1i4/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEx/MjczOTY5LTE1NjY3/MTY0MjYtOTA3OC5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/11273969',
#    'community': {'want': 35, 'have': 51},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'Israel',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Siren',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.',
#     'CBS Records Ltd.',
#     'CBS Records Ltd.',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Comforts Place',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Tape One'],
#    'type': 'release',
#    'genre': ['Rock', 'Pop'],
#    'style': ['Pop Rock', 'AOR'],
#    'id': 11425660,
#    'barcode': ['ACUM / BIEM', 'SIREN 7 A Q', 'SIREN 7 BQ'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/11425660-Cutting-Crew-Broadcast',
#    'catno': 'SIRE 7-1',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/RwByue86-s-bjD9_RBDpLFe4icS2K1E2IfnTNBUImys/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEx/NDI1NjYwLTE2Mjc3/MzY0MzQtMTA5NS5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/GatH0ZKWVSSsVMLInvodBtLPwMQPY0VousLA8cEDHIM/rs:fit/g:sm/q:90/h:610/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEx/NDI1NjYwLTE2Mjc3/MzY0MzQtMTA5NS5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/11425660',
#    'community': {'want': 32, 'have': 8},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'Argentina',
#    'year': '1988',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['RCA/Ariola-Ariola/RCA'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['New Wave', 'Pop Rock', 'Synth-pop'],
#    'id': 13341268,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/13341268-Cutting-Crew-Broadcast',
#    'catno': 'TLP 90073',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/3EcJnadWNStNWbxHLQOWjks1oanDMyR0PGr8Klvx0fE/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEz/MzQxMjY4LTE1NTI0/MDA1MjktNTU0My5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/byNwwZx2wAb9sijH229JmsodOlRzwXSTAyKLuc5ClYc/rs:fit/g:sm/q:90/h:450/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEz/MzQxMjY4LTE1NTI0/MDA1MjktNTU0My5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/13341268',
#    'community': {'want': 25, 'have': 3},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'Canada',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin',
#     'Virgin',
#     'Precision Lacquer',
#     'Siren Records',
#     'Siren Records',
#     'Virgin Records Canada Inc.',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Comforts Place',
#     'Virgin-Nymph Music Inc.',
#     'Copyright Control',
#     'The Lacquer Channel Limited',
#     'Cinram'],
#    'type': 'release',
#    'genre': ['Rock', 'Pop'],
#    'style': ['Pop Rock'],
#    'id': 1116513,
#    'barcode': ['VL 2363-A CR TLC-T', 'VL 2363-B CR TLC-T', 'G'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/1116513-Cutting-Crew-Broadcast',
#    'catno': 'VL 2363',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/vHW0gz8KHDK-1D7bAjC-P1kj4zuSpBbCrVK_7CXLgk4/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEx/MTY1MTMtMTI5MjA3/NDkwNy5qcGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/PCLKm5DeF9_Ms7DCpdXO8oQscaG3pO_6-rk7GR59RYA/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEx/MTY1MTMtMTI5MjA3/NDkwNy5qcGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/1116513',
#    'community': {'want': 69, 'have': 439},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'US',
#    'year': '1987',
#    'format': ['CD', 'Album'],
#    'label': ['Virgin Records America, Inc.', 'Virgin Records America, Inc.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 1438150,
#    'barcode': ['0 7567-90573-2 7'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/1438150-Cutting-Crew-Broadcast',
#    'catno': '2-90573',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/tSmu_XBoCCpSdqZ_TpFEium-FAXlKNEP9lpDj7QeexE/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/MzgxNTAtMTQ3MTA1/NjcxNS0zMTEwLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/XKDHiqFE7sOaElQFVGvfz9YuhCSZl241FBjm1GX-SJY/rs:fit/g:sm/q:90/h:597/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/MzgxNTAtMTQ3MTA1/NjcxNS0zMTEwLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/1438150',
#    'community': {'want': 45, 'have': 223},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD', 'qty': '1', 'descriptions': ['Album']}]},
#   {'country': 'US',
#    'year': '1987',
#    'format': ['CD', 'Album'],
#    'label': ['Virgin Records America, Inc.', 'Virgin Records America, Inc.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 9196568,
#    'barcode': ['0 7567-90573-2 7', '2-90573 MASTERED BY NIMBUS'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/9196568-Cutting-Crew-Broadcast',
#    'catno': '2-90573',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/j_6ZEzxRuscwoPaRXC-usiHqqwJkzRqB0k9k0M92oeM/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTkx/OTY1NjgtMTQ3Njc0/Mzg4MC0yNjkxLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/HGMFdW_pFoNF9jMjFqbmqDvtJzyywz_-Od7tJ11b9fA/rs:fit/g:sm/q:90/h:577/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTkx/OTY1NjgtMTQ3Njc0/Mzg4MC0yNjkxLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/9196568',
#    'community': {'want': 34, 'have': 96},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD', 'qty': '1', 'descriptions': ['Album']}]},
#   {'country': 'Japan',
#    'year': '1987',
#    'format': ['CD', 'Album', 'Reissue'],
#    'label': ['Virgin',
#     'Siren',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.',
#     'Copyright Control',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Toshiba EMI Ltd',
#     'Toshiba EMI Gotenba Plant'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 1956575,
#    'barcode': ['4988006611788',
#     'T4988 006 61178 8',
#     '32VD-1074 2B2 TO',
#     'JASRAC',
#     '28VB-1152'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/1956575-Cutting-Crew-Broadcast',
#    'catno': '32VD-1074',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/K48fY9WrBFneiJ8bkgVFusuxEp5-RUpb8HLWczoPemw/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/NTY1NzUtMTU3OTUw/NzYxNS01NzczLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/U2pdcxgGzg6vlyPwFsb1QMqAwiqyRj8f6sDtyL3JCSE/rs:fit/g:sm/q:90/h:531/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/NTY1NzUtMTU3OTUw/NzYxNS01NzczLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/1956575',
#    'community': {'want': 38, 'have': 34},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD',
#      'qty': '1',
#      'descriptions': ['Album', 'Reissue']}]},
#   {'country': 'Brazil',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Siren', 'Siren Records Ltd.', 'Siren Records Ltd.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Synth-pop', 'Pop Rock'],
#    'id': 4630206,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/4630206-Cutting-Crew-Broadcast',
#    'catno': '130.8012',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/BOzN0aLy1o3hABO1EoaAFJsNCNMmt2m6__b-2cGU03M/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTQ2/MzAyMDYtMTM3MDQ1/MTk5Ny05Nzg3Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/vkKAle3Jh2f92lUDFPykcZH9JFE96L8QkGM7K3oMZEM/rs:fit/g:sm/q:90/h:497/w:500/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTQ2/MzAyMDYtMTM3MDQ1/MTk5Ny05Nzg3Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/4630206',
#    'community': {'want': 40, 'have': 20},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'US',
#    'year': '1986',
#    'format': ['Cassette', 'Album'],
#    'label': ['Virgin',
#     'Virgin',
#     'WEA',
#     'WEA',
#     'Siren Records Ltd.',
#     'Virgin Records America, Inc.',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Comforts Place',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Precision Lacquer',
#     'Allied Record Company'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 14435455,
#    'barcode': ['075679057341', '0 7567-90573-4 1', 'AR'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/14435455-Cutting-Crew-Broadcast',
#    'catno': '7 90573-4',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/JbppQ4EWgFwEfEc0tbpdGWpqUOrfpTYS26AujjhL28U/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/NDM1NDU1LTE1NzQ0/ODc0NjAtODEyNi5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/_0VZuCOb_VRm3GkH5cPBm9-Svl6-GaX3bI8lPSUAv6A/rs:fit/g:sm/q:90/h:948/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/NDM1NDU1LTE1NzQ0/ODc0NjAtODEyNi5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/14435455',
#    'community': {'want': 18, 'have': 16},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette',
#      'qty': '1',
#      'text': 'AR, Dolby HX Pro',
#      'descriptions': ['Album']}]},
#   {'country': 'New Zealand',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Siren',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.',
#     'Virgin Records NZ Ltd.'],
#    'type': 'release',
#    'genre': ['Electronic'],
#    'style': ['Synth-pop'],
#    'id': 7112325,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/7112325-Cutting-Crew-Broadcast',
#    'catno': 'SIREN LP 7',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/9zwp4D6gBub5VtPBe6Pi5_2AxNsqeJzabygieRhY9QA/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTcx/MTIzMjUtMTU3NjUw/MzAwMC00OTUwLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/j15eVum8MdUixDklRKxaIRU2iAtBq7FWyXpfSYumG50/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTcx/MTIzMjUtMTU3NjUw/MzAwMC00OTUwLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/7112325',
#    'community': {'want': 36, 'have': 12},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'US',
#    'year': '1994',
#    'format': ['CD', 'Album', 'Reissue'],
#    'label': ['Virgin Records America, Inc.', 'EMI Jax'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 12789611,
#    'barcode': ['0 7777 86002 2 0', '86002 01# 03-14-94', 'SP 1-1-1 EMI JAX'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/12789611-Cutting-Crew-Broadcast',
#    'catno': '0777 7 86002 2 0',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/qGHOd_Lf4IsuMZt89yeDgLvHm0rirMluJaBDzCNAavk/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEy/Nzg5NjExLTE1NDE5/NzQ5MjctMTE0My5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/RCLvnA0HZCA35crrbqsJDsPg8zx4jVi4839opd_VpfE/rs:fit/g:sm/q:90/h:601/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEy/Nzg5NjExLTE1NDE5/NzQ5MjctMTE0My5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/12789611',
#    'community': {'want': 25, 'have': 6},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD',
#      'qty': '1',
#      'descriptions': ['Album', 'Reissue']}]},
#   {'country': 'UK',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album', 'Stereo'],
#    'label': ['Siren',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.',
#     'Chipping Norton Recording Studios',
#     'Mediasound',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Tape One'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['New Wave', 'Pop Rock', 'Synth-pop'],
#    'id': 1924649,
#    'barcode': ['5 012983 500717',
#     '5012983500717',
#     'SIRENLP 7 A-1U-1-1-1 Bilbo.Tape One',
#     'SIRENLP 7 B-1U-1-1-2 Bilbo.Tape One',
#     'SIRENLP 7 A-1U-1-3 BilBo.Tape One',
#     'SIRENLP 7 B-1U-1-3 BilBo.Tape One',
#     'SIRENLP 7 A-1U-1-1-1 Bilbo.Tape One',
#     'SIRENLP 7 B-1U-1-2-X1 BilBo.Tape One',
#     'SIRENLP 7 A-1U-1-2- Bilbo.Tape One',
#     'SIRENLP 7 B-1U-1-4- BilBo.Tape One'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/1924649-Cutting-Crew-Broadcast',
#    'catno': 'SIREN LP 7',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/IUfRuFUU5RlmV1mVMX6xyV_hY_4o4gnfI4ovfukA2kM/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/MjQ2NDktMTM0NzMy/NTYxMC0zMjg1Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/0YWpgg86hnzEOLnculQvl8gjXvDjAaCoSGRV8-baRC4/rs:fit/g:sm/q:90/h:454/w:454/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/MjQ2NDktMTM0NzMy/NTYxMC0zMjg1Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/1924649',
#    'community': {'want': 167, 'have': 665},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album', 'Stereo']}]},
#   {'country': 'US',
#    'year': '1986',
#    'format': ['Cassette', 'Album'],
#    'label': ['Virgin',
#     'Virgin',
#     'WEA',
#     'WEA',
#     'Siren Records Ltd.',
#     'Virgin Records America, Inc.',
#     'Specialty Records Corporation',
#     'Specialty Records Corporation',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
# ...
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/2249659-Cutting-Crew-Broadcast',
#    'catno': 'SIREN LP 7',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/h6klmbpQIwWWxy2IbNGVNIrxEpfafg16UYHcJvwGVNY/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTIy/NDk2NTktMTQ2NjM2/MDEwNS01MTQ4Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/zbPVdi1g-YINgNtT44Wv4xuP3pApwD0jev4bNy26Yl0/rs:fit/g:sm/q:90/h:598/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTIy/NDk2NTktMTQ2NjM2/MDEwNS01MTQ4Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/2249659',
#    'community': {'want': 62, 'have': 51},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'France',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin',
#     'Virgin France S.A.',
#     'Virgin France S.A.',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Comforts Place',
#     'Air Studios',
#     'Comforts Place',
#     'Utopia Studios',
#     'Tape One',
#     'Glory, Asnières',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 16465788,
#    'barcode': ['SACEM SACD SDRM SGDL',
#     'PM 262',
#     '5012983500717',
#     '350071 A 1  M6  354966 2',
#     '350071 B 1  M6  354967 2'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/16465788-Cutting-Crew-Broadcast',
#    'catno': '350071',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/oEUYe4_54GaskZEKgMLlRvyLf1BqntVlSPGCOYGDTrk/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE2/NDY1Nzg4LTE2MDg1/MDM0MjctNzY3Mi5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/c6s9HRwmXtc2lypaLr7cvy-gKlTyHNQzCudJZldjXDI/rs:fit/g:sm/q:90/h:601/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE2/NDY1Nzg4LTE2MDg1/MDM0MjctNzY3Mi5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/16465788',
#    'community': {'want': 19, 'have': 12},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'US',
#    'genre': ['Rock', 'Pop'],
#    'format': ['CD', 'Album', 'Reissue', 'Repress'],
#    'style': ['Pop Rock'],
#    'id': 21767398,
#    'label': ['Virgin Records America, Inc.',
#     'Siren Records Ltd.',
#     'Virgin Records America, Inc.',
#     'Capitol Records, Inc.',
#     'Sony DADC'],
#    'type': 'release',
#    'barcode': ['0 7777 86002 2 0',
#     '077778600220',
#     'A01 DIDX-223893 1',
#     'IFPI L328',
#     'IFPI 50D3'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/21767398-Cutting-Crew-Broadcast',
#    'catno': '0777 7 86002 2 0',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/pSDLcF5aQJtW_AoIGy0U6fzS6z7fSW4Mc1Y2AK7tKQU/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTIx/NzY3Mzk4LTE2NDIz/NzAzNzEtMjc0NS5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/fKJCR5xN2z03lt3ZOBQDMmCogM9QQKSplDJH_48rrHA/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTIx/NzY3Mzk4LTE2NDIz/NzAzNzEtMjc0NS5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/21767398',
#    'community': {'want': 1, 'have': 1},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD',
#      'qty': '1',
#      'descriptions': ['Album', 'Reissue', 'Repress']}]},
#   {'country': 'Europe',
#    'year': '1986',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin',
#     'Siren',
#     'Siren Records Ltd.',
#     'Siren Records Ltd.',
#     'Chipping Norton Recording Studios',
#     'Ridge Farm Studios',
#     'Terminal 24 Studios',
#     'Mediasound',
#     'Comforts Place',
#     'Air Studios',
#     'Comforts Place',
#     'TOPAC'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock'],
#    'id': 473136,
#    'barcode': ['DM 208 019 A',
#     'DM 208 019 B',
#     'DM 208019 A-1/10-86 III',
#     'DM 208019 B-1/10-86 II',
#     'DM 208019 A-1/10-86 II',
#     'DM 208019 B-1/10-86 II',
#     'GEMA STEMRA BIEM',
#     'LC 3098'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/473136-Cutting-Crew-Broadcast',
#    'catno': '208 019',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/SeD0j2tWaAMqLC-9tneD_dtL1rosf_wpcdL7tsiKTiA/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTQ3/MzEzNi0xNTc5MzYw/NDY0LTgzMTEuanBl/Zw.jpeg',
#    'cover_image': 'https://i.discogs.com/ZyOY_QN4ahvU5SpyJkjjmSz1n7sGxJZhLTL-VPlhDT8/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTQ3/MzEzNi0xNTc5MzYw/NDY0LTgzMTEuanBl/Zw.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/473136',
#    'community': {'want': 140, 'have': 1679},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'US',
#    'year': '1987',
#    'format': ['CD', 'Album', 'Club Edition'],
#    'label': ['Virgin',
#     'Virgin Records America, Inc.',
#     'Columbia House',
#     'Precision Lacquer',
#     'DADC'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 8460858,
#    'barcode': ['0 7567-90573-2 7',
#     '075679057327',
#     'DIDX-003062 1',
#     'DIDY 003062'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/8460858-Cutting-Crew-Broadcast',
#    'catno': 'V2 90573',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/niix8tLG2YA5L0KEuCQC5icI5dhe21Rx3N968Jjqv-c/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTg0/NjA4NTgtMTQ3MTA1/Njg4MC0zNzIxLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/fBHL55bpBUaP5OXEy0lBqQdZiNlJP3uuaNMdMnx9oH4/rs:fit/g:sm/q:90/h:597/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTg0/NjA4NTgtMTQ3MTA1/Njg4MC0zNzIxLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/8460858',
#    'community': {'want': 29, 'have': 46},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD',
#      'qty': '1',
#      'descriptions': ['Album', 'Club Edition']}]},
#   {'country': 'Mexico',
#    'year': '1986',
#    'format': ['Cassette', 'Album'],
#    'label': ['Virgin',
#     'Siren Records Ltd.',
#     'RCA/Ariola Internacional, S. De R.L. De C.V'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['New Wave', 'Pop Rock', 'Synth-pop'],
#    'id': 14061719,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/14061719-Cutting-Crew-Broadcast',
#    'catno': 'CS 715',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/y3ySpyzm1grhIEpjL-1jeZV585HOvA4y1XF48KP61Q4/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/MDYxNzE5LTE1NzE1/OTY2NDgtNDg4MS5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/kGzWMyVho1qAhT5KFT7pFvSin0USK6-3vKj20uUnzTM/rs:fit/g:sm/q:90/h:600/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/MDYxNzE5LTE1NzE1/OTY2NDgtNDg4MS5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/14061719',
#    'community': {'want': 16, 'have': 1},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette', 'qty': '1', 'descriptions': ['Album']}]},
#   {'country': 'Argentina',
#    'year': '1988',
#    'format': ['Cassette', 'Album'],
#    'label': ['RCA/Ariola-Ariola/RCA'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['New Wave', 'Pop Rock', 'Synth-pop'],
#    'id': 13701942,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/13701942-Cutting-Crew-Broadcast',
#    'catno': 'TMS 90073',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/qF8VdamN_1NXWOndJ--4uuH-3oww8OR-_sxb5TRAr0Q/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEz/NzAxOTQyLTE1NTkz/MjkzMjItMzE5Ny5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/OxzrAGnmn_gm6Cv6mA-14CQOP-M8xBS2vevBv39h5CA/rs:fit/g:sm/q:90/h:784/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEz/NzAxOTQyLTE1NTkz/MjkzMjItMzE5Ny5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/13701942',
#    'community': {'want': 18, 'have': 0},
#    'format_quantity': 1,
#    'formats': [{'name': 'Cassette', 'qty': '1', 'descriptions': ['Album']}]},
#   {'country': 'Mexico',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album'],
#    'label': ['Virgin'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 13169463,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/13169463-Cutting-Crew-Broadcast',
#    'catno': 'LAE-715',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/Lv3hz2Y9amFYXMuc0dj3lN2PyyJQrYvG5MItcr78HF8/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEz/MTY5NDYzLTE1NDky/NDI2ODYtOTU1OS5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/lKdbhPhQjARHfgnfPVnGQkLWxELfsKGsA5vUIQvpckU/rs:fit/g:sm/q:90/h:618/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEz/MTY5NDYzLTE1NDky/NDI2ODYtOTU1OS5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/13169463',
#    'community': {'want': 29, 'have': 24},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album']}]},
#   {'country': 'Peru',
#    'year': '1987',
#    'format': ['Vinyl', 'LP', 'Album', 'Stereo'],
#    'label': ['Ariola', '"El Virrey" Industrias Musicales S.A.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['New Wave', 'Synth-pop', 'Pop Rock'],
#    'id': 16261473,
#    'barcode': [],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/16261473-Cutting-Crew-Broadcast-',
#    'catno': 'PN-ARI 0208019.4',
#    'title': 'Cutting Crew - Broadcast ',
#    'thumb': 'https://i.discogs.com/ZJZMDRqMEwpWit9l9k84cdM3hWlr_DiS672XfNb2-e4/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE2/MjYxNDczLTE2MDYx/NjU0NDgtNTc5NC5q/cGVn.jpeg',
#    'cover_image': 'https://i.discogs.com/Azb6aqLyyoh9cRXWHf3vQlElVxEHn8TCsNsjpaq7_-4/rs:fit/g:sm/q:90/h:551/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE2/MjYxNDczLTE2MDYx/NjU0NDgtNTc5NC5q/cGVn.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/16261473',
#    'community': {'want': 18, 'have': 0},
#    'format_quantity': 1,
#    'formats': [{'name': 'Vinyl',
#      'qty': '1',
#      'descriptions': ['LP', 'Album', 'Stereo']}]},
#   {'country': 'US',
#    'year': '1992',
#    'format': ['CD', 'Album', 'Reissue'],
#    'label': ['Virgin Records America, Inc.'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 1929359,
#    'barcode': ['077778600220'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/1929359-Cutting-Crew-Broadcast',
#    'catno': '0777 7 86002 2 0',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/mog5ImuGu0U1ioGznUKeJ-z7inzfsgUKuvU5O1T9tC4/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/MjkzNTktMTQ3MTA1/NzAxOC0yMDgxLmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/wfjhdy1NqDXx_xcjoc6p9b8GtFK77TTF42kxvK1WZks/rs:fit/g:sm/q:90/h:597/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE5/MjkzNTktMTQ3MTA1/NzAxOC0yMDgxLmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/1929359',
#    'community': {'want': 37, 'have': 68},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD',
#      'qty': '1',
#      'descriptions': ['Album', 'Reissue']}]},
#   {'country': 'Japan',
#    'year': '1987',
#    'format': ['CD', 'Album', 'Reissue'],
#    'label': ['Virgin Japan', 'Siren', 'Virgin Japan Ltd'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock'],
#    'style': ['Pop Rock', 'Synth-pop'],
#    'id': 1438138,
#    'barcode': ['T4988 037 00035 3', 'JASRAC'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/1438138-Cutting-Crew-Broadcast',
#    'catno': 'VJD-32013',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/v6foUIdMRVzeElw_JlYu0A8-b9WydS-kApOeM7_w4UU/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/MzgxMzgtMTU1Mjgz/NDY2Ny03Mjk0Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/nDmR0jDI6eNBmu0Sp3RKGE4pC8yM679_2fmfUG2Znro/rs:fit/g:sm/q:90/h:515/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTE0/MzgxMzgtMTU1Mjgz/NDY2Ny03Mjk0Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/1438138',
#    'community': {'want': 36, 'have': 8},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD',
#      'qty': '1',
#      'descriptions': ['Album', 'Reissue']}]},
#   {'country': 'Russia',
#    'year': '2010',
#    'format': ['CD', 'Album', 'Reissue', 'Remastered', 'Unofficial Release'],
#    'label': ['Cherry Pop'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Synth-pop', 'Pop Rock'],
#    'id': 9495653,
#    'barcode': ['5013929424821', 'ifpily24 CRPOP48  01'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/9495653-Cutting-Crew-Broadcast',
#    'catno': 'CRPOP48',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/XJMSGcjHpKz-Id27-sL20ArFp06WpaL6TBMqZMd9vBY/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTk0/OTU2NTMtMTYzODE1/NTQ0My0yNDM1Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/ACoXTET4IxF1sL43kdbgMlYT3iQLuVZ2XxmKUuGvPEE/rs:fit/g:sm/q:90/h:563/w:561/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTk0/OTU2NTMtMTYzODE1/NTQ0My0yNDM1Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/9495653',
#    'community': {'want': 25, 'have': 4},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD',
#      'qty': '1',
#      'descriptions': ['Album',
#       'Reissue',
#       'Remastered',
#       'Unofficial Release']}]},
#   {'country': 'UK',
#    'year': '1986',
#    'format': ['CD', 'Album'],
#    'label': ['Siren', 'Nimbus'],
#    'type': 'release',
#    'genre': ['Electronic', 'Rock', 'Pop'],
#    'style': ['Synth-pop', 'Pop Rock'],
#    'id': 1077039,
#    'barcode': ['5 012983 500724',
#     '5012983500724',
#     'CD SIREN 7 ::   MASTERED BY NIMBUS',
#     'CD SIREN 7 .   MASTERED BY NIMBUS',
#     'AAD',
#     'B000092AHD'],
#    'user_data': {'in_wantlist': False, 'in_collection': False},
#    'master_id': 65301,
#    'master_url': 'https://api.discogs.com/masters/65301',
#    'uri': '/release/1077039-Cutting-Crew-Broadcast',
#    'catno': 'CD SIREN 7',
#    'title': 'Cutting Crew - Broadcast',
#    'thumb': 'https://i.discogs.com/W8wGKozIeEoRthQjoVgu9thBuwC_Bneuopn1_GZUZVg/rs:fit/g:sm/q:40/h:150/w:150/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEw/NzcwMzktMTU4Njc3/MzA5NC04NzA1Lmpw/ZWc.jpeg',
#    'cover_image': 'https://i.discogs.com/jHqd-HffkCDOtN_dyzEWI5tVXRNgvaq1nWRqaeBweHg/rs:fit/g:sm/q:90/h:588/w:600/czM6Ly9kaXNjb2dz/LWltYWdlcy9SLTEw/NzcwMzktMTU4Njc3/MzA5NC04NzA1Lmpw/ZWc.jpeg',
#    'resource_url': 'https://api.discogs.com/releases/1077039',
#    'community': {'want': 57, 'have': 177},
#    'format_quantity': 1,
#    'formats': [{'name': 'CD', 'qty': '1', 'descriptions': ['Album']}]}]}

# %%
generos = ['House', 'Electro', 'Disco']
#generos = ['Pop']

# %%
mira = ",".join(generos)

# %%
print(mira)
print('House,Electro,Disco')
# Out:
# House,Electro,Disco
# House,Electro,Disco

# %%
po
