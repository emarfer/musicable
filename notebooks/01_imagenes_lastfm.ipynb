# %%
import os
import requests
import sys
sys.path.append('../src')
import sqltools as sqt

from PIL import Image
from io import BytesIO

import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18304\2406139384.py in <module>
#       3 import sys
#       4 sys.path.append('../src')
# ----> 5 import sqltools as sqt
#       6
#       7 from PIL import Image
#
# ~\Proyectos_personales\musicable\notebooks\../src\sqltools.py in <module>
#       2 import os
#       3 import sqlalchemy as alch
# ----> 4 import dotenv
#       5 import datetime
#       6 import time
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
# token lastfm
keylast = os.getenv("keylast")

# %%
l_user = 'sinatxester' #usuario lastfm
limit = 1000 #limite de resultados por página de la request
uts_num = sqt.maxuts() + 1 #último uts para cargar datos y limitar

# %%
#url request
url = f'http://ws.audioscrobbler.com/2.0/?method=user.getrecenttracks&user={l_user}&limit={limit}&from={uts_num}&api_key={keylast}&format=json'

# %%
temas = requests.get(url).json()['recenttracks']['track'] #request a la api para tener unos cuantos temas sobre los que trabajar

# %%
tema = random.choice(temas) # genero un tema en concreto

# %%
tema['image'] # urls de imagenes.
# Out:
# [{'size': 'small',
#   '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/3d98da674e9abc65ecc5f1c976ec8a72.jpg'},
#  {'size': 'medium',
#   '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/3d98da674e9abc65ecc5f1c976ec8a72.jpg'},
#  {'size': 'large',
#   '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/3d98da674e9abc65ecc5f1c976ec8a72.jpg'},
#  {'size': 'extralarge',
#   '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/3d98da674e9abc65ecc5f1c976ec8a72.jpg'}]

# %%
for t in tema['image']:
    print(t.values())
#t[0]: small 
#t[1]: medium 
#t[2]: large 
#t[3]: extralarge
# Out:
# dict_values(['small', 'https://lastfm.freetls.fastly.net/i/u/34s/3d98da674e9abc65ecc5f1c976ec8a72.jpg'])
# dict_values(['medium', 'https://lastfm.freetls.fastly.net/i/u/64s/3d98da674e9abc65ecc5f1c976ec8a72.jpg'])
# dict_values(['large', 'https://lastfm.freetls.fastly.net/i/u/174s/3d98da674e9abc65ecc5f1c976ec8a72.jpg'])
# dict_values(['extralarge', 'https://lastfm.freetls.fastly.net/i/u/300x300/3d98da674e9abc65ecc5f1c976ec8a72.jpg'])

# %%
for ima in tema['image']:
    print(ima['#text']) #urls de las imágenes
# Out:
# https://lastfm.freetls.fastly.net/i/u/34s/3d98da674e9abc65ecc5f1c976ec8a72.jpg
# https://lastfm.freetls.fastly.net/i/u/64s/3d98da674e9abc65ecc5f1c976ec8a72.jpg
# https://lastfm.freetls.fastly.net/i/u/174s/3d98da674e9abc65ecc5f1c976ec8a72.jpg
# https://lastfm.freetls.fastly.net/i/u/300x300/3d98da674e9abc65ecc5f1c976ec8a72.jpg

# %% [markdown]
# ## How do I read image data from a URL in Python?
# - [link a stackoverflow](https://stackoverflow.com/questions/7391945/how-do-i-read-image-data-from-a-url-in-python)
# ```python
# img_src
# response = requests.get(img_src)
# image = Image.open(BytesIO(response.content))
# image.show()
# ```

# %%
for imagen in tema['image']: 
    img_src = imagen['#text']
    response = requests.get(img_src)
    image = Image.open(BytesIO(response.content))
    image.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=34x34 at 0x7FC080E2D9D0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=64x64 at 0x7FC0C923B1C0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=174x174 at 0x7FC080E82D90>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7FC080E82EE0>
