# %%
import sqlalchemy as alch
import os
import dotenv
dotenv.load_dotenv()
import pandas as pd
import sys
sys.path.append('../src')
import apilast as als
import sqltools as sqt
import listas as lst
import requests
import datetime
import shutil
import numpy as np
import random
import tinytag
from tinytag import TinyTag

# %%
passw = os.getenv("mysql")
dbName = "musicablecero"
connectionData = f"mysql+pymysql://root:{passw}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %%
tempo = 145

# %%
last_tempo = pd.read_sql_query(f'''
select lr.id_lr as temp_id,t.id_art, t.artist,t.id_alb,t.album,t.id_can,t.title,t.secs, t.mins,t.folder,t.archivo

, lr.reps as temp_reps
from listas_rep lr left join total t on t.id_Can = lr.id_can
where lr.id_tem = {tempo}
order by lr.id_lr;
''',engine)

# %%
last_tempo.head()
# Out:
#    temp_id  id_art         artist  id_alb                               album  \
# 0     7496      32  Maldita Nerea      35          El Secreto de las Tortugas
# 1     7497     161         Amaral     265                     Estrella De Mar
# 2     7498     314      Meat Loaf     466  Bat Out of Hell II: Back Into Hell
# 3     7499     100   Los Secretos    4007                      Adiós Tristeza
# 4     7500    1206  Mary J. Blige    1922                    The Breakthrough
#
#    id_can                                              title  secs   mins  \
# 0      35  El Secreto De Las Tortugas (ft. Los Delinqüentes)   248  04:08
# 1     322                                         ¿Qué será?   202  03:22
# 2     791     I'd Do Anything for Love (But I Won't Do That)   324  05:24
# 3   19951                                     Adiós Tristeza   205  03:25
# 4    4255                                       One (ft. U2)   261  04:21
#
#                                               folder  \
# 0                           H:\Music\V.A\Miscelánea\
# 1  H:\Music\Pop Rock en español y movida\Amaral\2...
# 2  H:\Music\Metal, hard rock\Meat Loaf\1993 Bat O...
# 3  H:\Music\Pop Rock en español y movida\Los Secr...
# 4                           H:\Music\V.A\Miscelánea\
#
#                                              archivo  temp_reps
# 0  Maldita Nerea - El Secreto De Las Tortugas (Ft...          7
# 1                                  05 ¿qué Será .mp3          7
# 2  12 I'd Do Anything For Love (But I Won't Do Th...          7
# 3                              11 Adiós Tristeza.mp3          7
# 4                   Mary J. Blige - One (ft. U2).mp3          7

# %%
ruta = '../../../'

# %%
last_tempo['ruta_relativa'] = last_tempo.apply(lambda x: lst.relative_rute(x['folder'],x['archivo'],ruta),axis=1)

# %%
def copy_lista(tempo,list_rep):
    '''
    recibe un dataframe con los datos de la lista de reproducción
    itera por todo el dataframe
    copia los archivos en la ruta especificada 
    modifica el nombre de los archivos:
            - orden en lista artista - título (el orden en lista se autocompleta con ceros delante)
            - 01 Amaral - Sin ti no soy nada
    
    '''
    tot = len(list_rep) #para autocompletar los ceros el orden de los archivos
    ceros = len(str(tot))  
    nuevacar = foldertemp(carpeta,tempo)
    
    dst = nuevacar #destino de los archivos
    for i, r in list_rep.iterrows():
        if r.archivo not in os.listdir(nuevacar):
            src = r.ruta+r.archivo
            shutil.copy2(src,dst)
            #print(f'{r.archivo} copiado en {nuevacar}')
            order = addceros(i,len(list_rep)) #autocompletar con ceros el orden
            old_name = nuevacar+'/'+r.archivo
            new_name = f'{nuevacar}/{order} {cambiobarra(r.artist)} - {cambiobarra(r.title)}.{r.tipo}'
            os.rename(old_name, new_name)
            #print(f'{r.archivo} renombrado a {new_name}')
            
        else:
            #print(f'YA EXISTE {r.archivo} en {tempo.upper()} vamos a cambiar su nombre')
            old_name = nuevacar+'/'+r.archivo
            order = addceros(i,len(list_rep))
            new_name = f'{nuevacar}/{order} {cambiobarra(r.artist)} - {cambiobarra(r.title)}.{r.tipo}'
            os.rename(old_name, new_name)
            #print(f'{r.archivo} renombrado a {new_name}')

# %%
ruta_destino =

# %%
last_tempo.ruta_relativa.loc[2]
# Out:
# "../../../Music/Metal, hard rock/Meat Loaf/1993 Bat Out Of Hell II - Back Into Hell/12 I'd Do Anything For Love (But I Won't Do That).mp3"

# %%
#change rute
os.listdir('../../../')

# %%
last_tempo['ruta_rel'] = last_tempo.folder.str.replace('\\','/',regex=True).str.replace('H:/','../../../') + last_tempo.archivo

# %%
last_tempo.head()

# %%
os.listdir(last_tempo.folder.str.replace('\\','/',regex=True).str.replace('H:/','../../../').iloc[25])

# %%
Pri_2010_02 = pd.read_sql_query(f'''
        SELECT l.id_lr, l.id_can, l.reps, t.artist, t.album, t.title, t.folder,t.archivo, t.secs, t.kbs, t.tipo
        FROM listas_rep l JOIN total t ON t.id_can = l.id_can
        WHERE l.id_tem = (SELECT id_tem FROM temporadas WHERE temporada = 'Pri_2010_02')
        ORDER BY id_lr;
        ''',engine)

# %%
Pri_2010_02
# Out:
#     id_lr  id_can  reps                     artist  \
# 0       1     137     3                        Dio
# 1       2     133     3               Alice Cooper
# 2       3     130     3                  Helloween
# 3       4     126     3             Sonata Arctica
# 4       5     124     3      Paquita La Del Barrio
# 5       6     169     3             La Vela Puerca
# 6       7     197     3             Niños Mutantes
# 7       8     262     3                Luis Ramiro
# 8       9     285     3  Muchachito Bombo Infierno
# 9      10     287     3              Liza Minnelli
# 10     11     307     3             Chris de Burgh
# 11     12       6     4          La Cabra Mecánica
# 12     13      14     4                    Marisol
# 13     14      30     4                 Mägo de Oz
# 14     15      18     4            The Cranberries
# 15     16      59     4                 Guano Apes
# 16     17     229     4                     Amaral
# 17     18      57     5                   Bon Jovi
# 18     19      53     5                     Pereza
# 19     20      70     5                      Vixen
# 20     21     109     5              Gloria Gaynor
# 21     22     204     5                      Milow
# 22     23      68     6                      Ska-P
#
#                                 album                            title  \
# 0                          Holy Diver                       Holy Diver
# 1                         Hey Stoopid              Love's a Loaded Gun
# 2   Keeper Of The Seven Keys, Part II                       I Want Out
# 3                           Successor                              Shy
# 4                        Taco Placero                Rata de dos patas
# 5                  De bichos y flores                         El Viejo
# 6                  Todo es el momento  Te favorece tanto estar callada
# 7                 Dramas Y Caballeros       Paraíso Con Gastos Pagados
# 8                      Idas y vueltas             La pandilla voladora
# 9                             Cabaret                          Cabaret
# 10                     Into The Light                  The Lady in Red
# 11                Vestidos De Domingo                        Felicidad
# 12                  30 Grandes Éxitos                  Typical spanish
# 13                               Gaia            La Costa Del Silencio
# 14                   Bury the Hatchet              Just My Imagination
# 15                Don't Give Me Names                     Big in Japan
# 16        Una pequeña parte del mundo            Siento que te extraño
# 17                     Keep The Faith             If I Was Your Mother
